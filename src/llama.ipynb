# %%
# !pip install tiktoken
# Out:
# Collecting tiktoken
#   Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.7 kB)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2024.11.6)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.11/dist-packages (from tiktoken) (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.26.0->tiktoken) (2025.1.31)
# Downloading tiktoken-0.9.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 12.9 MB/s eta 0:00:00
# Installing collected packages: tiktoken
# Successfully installed tiktoken-0.9.0

# %%
import jax
import jax.numpy as jnp
from flax import nnx
import numpy as np
from functools import lru_cache
from dataclasses import dataclass
from typing import Any
from jax import checkpoint

# %%
@dataclass
class ModelArgs:
    vocab_size: int
    context_length: int
    embedding_dim: int
    n_heads: int
    n_layers: int
    hidden_dim: int
    n_kv_groups: int
    rope_base: float
    rope_freq: dict
    param_dtype: jnp.dtype = jnp.float32
    dtype: jnp.dtype = jnp.bfloat16

# %% [markdown]
# ## Model Definition

# %%
class FeedForward(nnx.Module):
    def __init__(self, args: ModelArgs, rngs: nnx.Rngs):
        super().__init__()
        self.fc1 = nnx.Linear(args.embedding_dim, args.hidden_dim, rngs=rngs, use_bias=False, dtype=args.dtype)
        self.fc2 = nnx.Linear(args.embedding_dim, args.hidden_dim, rngs=rngs, use_bias=False, dtype=args.dtype)
        self.fc3 = nnx.Linear(args.hidden_dim, args.embedding_dim, rngs=rngs, use_bias=False, dtype=args.dtype)

    def __call__(self, x):
        x_fc1 = self.fc1(x)
        x_fc2 = self.fc2(x)
        x = nnx.silu(x_fc1) * x_fc2
        return self.fc3(x)

def precompute_rope_params(head_dim, theta_base=10_000, context_length=4096, freq_config=None):
    assert head_dim % 2 == 0, "Embedding dimension must be even"

    # Compute inverse frequencies
    inv_freq = 1.0 / (theta_base ** (jnp.arange(0, head_dim, 2) / head_dim))

    # Frequency adjustments (optional)
    if freq_config is not None:
      low_freq_wavelen = freq_config["original_context_length"] / freq_config["low_freq_factor"]
      high_freq_wavelen = freq_config["original_context_length"] / freq_config["high_freq_factor"]

      wavelen = 2 * jnp.pi / inv_freq

      inv_freq_llama = jnp.where(
          wavelen > low_freq_wavelen, inv_freq / freq_config["factor"], inv_freq
      )

      smooth_factor = (
          (freq_config["original_context_length"] / wavelen - freq_config["low_freq_factor"])
          / (freq_config["high_freq_factor"] - freq_config["low_freq_factor"])
      )

      smoothed_inv_freq = (
          (1 - smooth_factor) * (inv_freq / freq_config["factor"]) + smooth_factor * inv_freq
      )

      is_medium_freq = (wavelen <= low_freq_wavelen) & (wavelen >= high_freq_wavelen)
      inv_freq_llama = jnp.where(is_medium_freq, smoothed_inv_freq, inv_freq_llama)

      inv_freq = inv_freq_llama

    # Position indices
    positions = jnp.arange(context_length)

    # Compute rotary angles
    angles = positions[:, None] * inv_freq[None, :]  # (context_len, head_dim // 2)

    # Duplicate for interleaved dimensions
    angles = jnp.concatenate([angles, angles], axis=-1)  # (context_len, head_dim)

    # Precompute sin/cos
    cos = jnp.cos(angles)
    sin = jnp.sin(angles)

    return cos, sin

def compute_rope(x, cos, sin):
    # x: (batch, heads, seq_len, head_dim)
    batch, heads, seq_len, head_dim = x.shape
    assert head_dim % 2 == 0, "Head dim must be even"

    x1 = x[..., :head_dim // 2]
    x2 = x[..., head_dim // 2:]

    # Broadcast cos/sin: (1, 1, seq_len, head_dim)
    cos = cos[:seq_len, :][None, None, :, :]
    sin = sin[:seq_len, :][None, None, :, :]

    # Rotary transformation
    rotated = jnp.concatenate([-x2, x1], axis=-1)
    return (x * cos) + (rotated * sin)


class GroupedQueryAttention(nnx.Module):
    def __init__(
        self, d_in, d_out, context_length, num_heads, num_kv_groups,
        rope_base=10_000, rope_config=None, dtype=jnp.float32, rngs=nnx.Rngs
    ):
        assert d_out % num_heads == 0, "d_out must be divisible by num_heads"
        assert num_heads % num_kv_groups == 0, "num_heads must be divisible by num_kv_groups"

        self.d_out = d_out
        self.num_heads = num_heads
        self.num_kv_groups = num_kv_groups
        self.head_dim = d_out // num_heads
        self.group_size = num_heads // num_kv_groups

        self.W_query = nnx.Linear(d_in, d_out, use_bias=False, dtype=dtype, rngs=rngs)
        self.W_key = nnx.Linear(d_in, num_kv_groups * self.head_dim, use_bias=False, dtype=dtype, rngs=rngs)
        self.W_value = nnx.Linear(d_in, num_kv_groups * self.head_dim, use_bias=False, dtype=dtype, rngs=rngs)
        self.out_proj = nnx.Linear(d_out, d_out, use_bias=False, dtype=dtype, rngs=rngs)

        # Direct JAX computation without caching
        cos, sin = precompute_rope_params(
            head_dim=self.head_dim,
            theta_base=rope_base,
            context_length=context_length,
            freq_config=rope_config
        )
        self.cos = cos.astype(dtype)
        self.sin = sin.astype(dtype)
        self.rope_base = rope_base
        self.freq_config = rope_config
        self.context_length = context_length

    def __call__(self, x: jax.Array) -> jax.Array:
        b, seq_len, _ = x.shape

        q = self.W_query(x).reshape(b, seq_len, self.num_heads, self.head_dim)
        k = self.W_key(x).reshape(b, seq_len, self.num_kv_groups, self.head_dim)
        v = self.W_value(x).reshape(b, seq_len, self.num_kv_groups, self.head_dim)

        # Transpose for attention shape: (b, heads, seq, dim)
        q = jnp.transpose(q, (0, 2, 1, 3))
        k = jnp.transpose(k, (0, 2, 1, 3))
        v = jnp.transpose(v, (0, 2, 1, 3))

        # cos, sin = precompute_rope_params(
        #     head_dim=self.head_dim,
        #     theta_base=self.rope_base,
        #     context_length=seq_len,  # not the full context
        #     freq_config=self.freq_config
        # )
        # cos = cos.astype(x.dtype)
        # sin = sin.astype(x.dtype)
        cos = self.cos[:seq_len]
        sin = self.sin[:seq_len]

        # Apply RoPE
        q = compute_rope(q, cos, sin)
        k = compute_rope(k, cos, sin)

        # Expand k and v from kv_groups to full head count
        k = jnp.repeat(k, self.group_size, axis=1)
        v = jnp.repeat(v, self.group_size, axis=1)

        # Attention scores
        attn_scores = jnp.einsum("bhqd,bhkd->bhqk", q, k)  # (b, heads, query_len, key_len)

        # Apply causal mask
        mask = jnp.tril(jnp.ones((seq_len, seq_len), dtype=bool))
        # attn_scores = jnp.where(mask, -jnp.inf, attn_scores)
        attn_scores = jnp.where(mask, attn_scores, -jnp.inf)


        # Softmax
        attn_weights = jax.nn.softmax(attn_scores / jnp.sqrt(self.head_dim), axis=-1)

        # Attention output
        context = jnp.einsum("bhqk,bhkd->bhqd", attn_weights, v)
        context = jnp.transpose(context, (0, 2, 1, 3))  # (b, seq, heads, dim)
        context = context.reshape(b, seq_len, self.d_out)

        return self.out_proj(context)

class TransformerBlock(nnx.Module):
    def __init__(self, args: ModelArgs, rngs: nnx.Rngs):
        super().__init__()


        self.att = GroupedQueryAttention(
            d_in=args.embedding_dim,
            d_out=args.embedding_dim,
            context_length=args.context_length,
            num_heads=args.n_heads,
            num_kv_groups=args.n_kv_groups,
            rope_base=args.rope_base,
            rope_config=args.rope_freq,
            dtype=args.dtype,
            rngs=rngs
        )
        self.ff = FeedForward(args, rngs=rngs)
        self.norm1 = nnx.RMSNorm(args.embedding_dim, epsilon=1e-5, rngs=rngs)
        self.norm2 = nnx.RMSNorm(args.embedding_dim, epsilon=1e-5, rngs=rngs)

    def __call__(self, x, cos=None, sin=None, cache=None, cache_index=None):
        shortcut = x
        x = self.norm1(x)

        x = checkpoint(self.att)(x.astype(jnp.bfloat16))
        x = x + shortcut

        shortcut = x
        x = self.norm2(x)
        x = checkpoint(self.ff)(x.astype(jnp.bfloat16))
        x = x + shortcut
        return x


class Llama3Model(nnx.Module):
    def __init__(self, args: ModelArgs, rngs: nnx.Rngs):
        super().__init__()

        self.tok_emb = nnx.Embed(
            num_embeddings=args.vocab_size,
            features=args.embedding_dim,
            dtype=args.dtype,
            param_dtype=args.param_dtype,
            rngs=rngs
        )

        self.trf_blocks = [
            TransformerBlock(args, rngs=rngs)
            for _ in range(args.n_layers)
        ]

        self.final_norm = nnx.RMSNorm(
            args.embedding_dim,
            epsilon=1e-5,
            dtype=args.dtype,
            param_dtype=args.param_dtype,
            rngs=rngs
        )

        self.out_head = nnx.Linear(
            args.embedding_dim,
            args.vocab_size,
            use_bias=False,
            dtype=args.dtype,
            param_dtype=args.param_dtype,
            rngs=rngs
        )

    def __call__(self, in_idx: jax.Array):
        x = self.tok_emb(in_idx)
        for block in self.trf_blocks:
            x = block(x)
        x = self.final_norm(x)
        logits = self.out_head(x.astype(jnp.bfloat16))
        return logits

# %%
# Define model arguments using LLAMA32_CONFIG
LLAMA32_CONFIG = {
    "vocab_size": 128_256,
    "context_length": 131_072,
    "embedding_dim": 2048,
    "n_heads": 32,
    "n_layers": 16,
    "hidden_dim": 8192,
    "n_kv_groups": 8,
    "rope_base": 500_000.0,
    "dtype": jnp.bfloat16,
    "param_dtype": jnp.bfloat16,

    "rope_freq": {
        "factor": 32.0,
        "low_freq_factor": 1.0,
        "high_freq_factor": 4.0,
        "original_context_length": 8192,
    }
}

# %%
# Save the old context length
old_context_length = LLAMA32_CONFIG["context_length"]

# Set new context length
LLAMA32_CONFIG["context_length"] = 8192

# Rescale theta (RoPE base)
def rescale_theta(theta_old, context_length_old, context_length_new):
    scaling_factor = context_length_new / context_length_old
    return theta_old * scaling_factor

old_context_length = LLAMA32_CONFIG["context_length"]

# Set new context length
LLAMA32_CONFIG["context_length"] = 8192

LLAMA32_CONFIG["rope_base"] = rescale_theta(
    LLAMA32_CONFIG["rope_base"],
    old_context_length,
    LLAMA32_CONFIG["context_length"]
)

print("New RoPE theta:", LLAMA32_CONFIG["rope_base"])
# Out:
# New RoPE theta: 31250.0

# %% [markdown]
# ### Miscellaneous Checks

# %%
args = ModelArgs(**LLAMA32_CONFIG)

rngs = nnx.Rngs(0)

# Instantiate the model
model = Llama3Model(args=args, rngs=rngs)
rng = jax.random.PRNGKey(0)


# # Example dummy input (batch_size=1, seq_len=128)
# dummy_input = jnp.ones((1, 128), dtype=jnp.int32)

# # Forward pass (no cache in this case)
# logits = model(dummy_input)
# print("Logits shape:", logits.shape)  # Should be (1, 128, vocab_size)

# %%
# Example dummy input (batch_size=1, seq_len=128)
dummy_input = jnp.ones((1, 128), dtype=jnp.int32)

# Forward pass (no cache in this case)
logits = model(dummy_input)
print("Logits shape:", logits.shape)  # Should be (1, 128, vocab_size)
# Out:
# Logits shape: (1, 128, 128256)

# %%
type(model.tok_emb.embedding.value)
# Out:
# jaxlib.xla_extension.ArrayImpl

# %%
init_weights = nnx.state(model)

init_weights
# Out:
# State({
#   'final_norm': {
#     'scale': VariableState( # 2,048 (4.1 KB)
#       type=Param,
#       value=Array([1, 1, 1, ..., 1, 1, 1], dtype=bfloat16)
#     )
#   },
#   'out_head': {
#     'kernel': VariableState( # 262,668,288 (525.3 MB)
#       type=Param,
#       value=Array([[-0.0336914, 0.0167236, -0.013855, ..., 0.0314941, 0.00521851,
#               -0.00765991],
#              [0.00135803, -0.000492096, 0.00958252, ..., 0.00570679,
#               -0.00282288, 0.000492096],
#              [-0.0197754, 0.0402832, -0.0303955, ..., 0.0117188, 0.00196838,
#               -0.0167236],
#              ...,
#              [0.0159912, -0.0427246, 0.00723267, ..., 0.0142212, -0.013855,
#               -0.0314941],
#              [-0.0253906, -0.0197754, -0.0303955, ..., -0.0117188, -0.0197754,
#               0.0117188],
#              [0.0117188, -0.0148315, -0.0349121, ..., 0.0032196, -0.0159912,
#               -0.0214844]], dtype=bfloat16)
#     )
#   },
#   'tok_emb': {
#     'embedding': VariableState( # 262,668,288 (525.3 MB)
#       type=Param,
#       value=Array([[0.0255127, -0.0078125, 0.0317383, ..., -0.0349121, 0.000541687,
#               -0.0142212],
#              [0.0395508, 0.015564, 0.0274658, ..., 0.0230713, 0.000972748,
#               0.0305176],
#              [-0.012146, 0.0292969, 0.00674438, ..., -0.0152588, 0.0203857,
#               -0.0383301],
#              ...,
#              [-0.00970459, 0.0224609, -0.0111084, ..., -0.00601196, -0.0078125,
#               -0.0175781],
#              [-0.00163269, 0.0217285, -0.0137329, ..., -0.00878906, 0.00358582,
#               0.0129395],
#              [-0.00119019, -0.0288086, 0.0263672, ..., -0.0101929, -0.0187988,
#               -0.0101929]], dtype=bfloat16)
#     )
#   },
#   'trf_blocks': {
#     0: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1,048,576 (4.2 MB)
#             type=Param,
#             value=Array([[ 0.03004296,  0.03128923, -0.0097964 , ...,  0.00754088,
#                      0.0088112 , -0.02784548],
#                    [ 0.00287186, -0.00912509, -0.01747254, ..., -0.03776326,
#                     -0.00872656, -0.02120081],
#                    [-0.00716027,  0.00198702, -0.01813753, ...,  0.01040426,
#                      0.0119301 , -0.03521422],
#                    ...,
#                    [-0.00467393, -0.02566953, -0.00106677, ..., -0.00056204,
#                     -0.01863984,  0.03842844],
#                    [ 0.02270183,  0.00375482,  0.01806989, ...,  0.04534518,
#                     -0.01045258,  0.00537805],
#                    [ 0.02035493,  0.0007719 , -0.01734035, ..., -0.00446348,
#                      0.00175723,  0.00547357]], dtype=float32)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 4,194,304 (16.8 MB)
#             type=Param,
#             value=Array([[-4.73541543e-02, -4.32151631e-02,  4.92542889e-03, ...,
#                     -8.06368794e-03, -1.66442934e-02, -1.83037351e-04],
#                    [ 4.00359370e-02, -8.98429099e-03,  6.34861691e-03, ...,
#                     -1.03675388e-02, -4.16224636e-03, -2.58967802e-02],
#                    [-1.63743254e-02, -4.34714137e-03, -1.00868456e-02, ...,
#                      1.08453985e-02, -1.27026495e-02, -1.09681729e-02],
#                    ...,
#                    [-1.26589956e-02,  7.01367389e-04,  1.36776390e-02, ...,
#                      5.36433328e-03, -7.50382105e-03, -1.86496805e-02],
#                    [-4.82714884e-02,  3.87981883e-03,  4.09566477e-04, ...,
#                     -6.65281434e-03,  8.03693329e-05,  5.93311666e-03],
#                    [-3.60723846e-02,  2.44903527e-02, -5.01282234e-03, ...,
#                     -4.31511458e-03, -1.04693295e-02, -3.31797712e-02]],      dtype=float32)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1,048,576 (4.2 MB)
#             type=Param,
#             value=Array([[-0.01482168,  0.01488895,  0.03765937, ..., -0.01429515,
#                      0.03036427,  0.00643065],
#                    [ 0.02073961, -0.02217922,  0.02423284, ...,  0.02013692,
#                      0.04488898, -0.03594664],
#                    [ 0.04247073,  0.01207807,  0.01202372, ...,  0.00505239,
#                     -0.01417119,  0.0278015 ],
#                    ...,
#                    [ 0.0279021 , -0.010315  , -0.04703969, ...,  0.02157837,
#                     -0.03599623, -0.01505683],
#                    [-0.02774147,  0.021388  , -0.03479505, ..., -0.019624  ,
#                     -0.04891947, -0.01369715],
#                    [ 0.00728361, -0.02881053,  0.00757266, ...,  0.01461051,
#                     -0.03486468,  0.02238161]], dtype=float32)
#           )
#         },
#         'cos': Array([[1, 1, 1, ..., 1, 1, 1],
#                [0.539062, 0.75, 0.867188, ..., 1, 1, 1],
#                [-0.416016, 0.123047, 0.5, ..., 1, 1, 1],
#                ...,
#                [-0.425781, 0.515625, -0.980469, ..., 1, 1, 1],
#                [-0.992188, -0.178711, -0.75, ..., 1, 1, 1],
#                [-0.644531, -0.785156, -0.318359, ..., 1, 1, 1]], dtype=bfloat16),
#         'out_proj': {
#           'kernel': VariableState( # 4,194,304 (16.8 MB)
#             type=Param,
#             value=Array([[-0.02402792,  0.01453614, -0.03001189, ..., -0.02796853,
#                      0.00474817, -0.0106937 ],
#                    [ 0.01946524,  0.0008112 ,  0.02576433, ...,  0.04180972,
#                     -0.01019916, -0.02949816],
#                    [-0.03627096, -0.01071917, -0.00422091, ...,  0.00578565,
#                     -0.0009181 ,  0.0098193 ],
#                    ...,
#                    [ 0.01552213,  0.01935084, -0.02985326, ...,  0.05001043,
#                      0.04159156,  0.00192771],
#                    [ 0.03395587, -0.01843184, -0.01119521, ...,  0.00240494,
#                     -0.02442259,  0.00347065],
#                    [-0.02073972, -0.02613571,  0.02649912, ...,  0.00213793,
#                     -0.00934926,  0.00225759]], dtype=float32)
#           )
#         },
#         'sin': Array([[0, 0, 0, ..., 0, 0, 0],
#                [0.839844, 0.664062, 0.5, ..., 2.63751e-06, 1.90735e-06,
#                 1.37836e-06],
#                [0.910156, 0.992188, 0.867188, ..., 5.27501e-06, 3.8147e-06,
#                 2.75671e-06],
#                ...,
#                [0.90625, 0.855469, -0.198242, ..., 0.0216064, 0.015625,
#                 0.0112915],
#                [0.131836, 0.984375, -0.660156, ..., 0.0216064, 0.015625,
#                 0.0112915],
#                [-0.761719, 0.617188, -0.949219, ..., 0.0216064, 0.015625,
#                 0.0112915]], dtype=bfloat16)
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 16,777,216 (67.1 MB)
#             type=Param,
#             value=Array([[ 0.01518445,  0.00765136,  0.02947173, ..., -0.01747243,
#                      0.02920585, -0.00418013],
#                    [-0.00148133, -0.04405906, -0.03476052, ..., -0.02314715,
#                     -0.01549911, -0.01293684],
#                    [-0.03306118,  0.00564837, -0.02405342, ...,  0.01754216,
#                     -0.01048706, -0.02330276],
#                    ...,
#                    [ 0.02584101, -0.0116683 , -0.00137868, ..., -0.00038124,
#                     -0.04673976,  0.02663385],
#                    [-0.01957286, -0.04962119, -0.00341731, ...,  0.00505629,
#                     -0.01711495, -0.02264993],
#                    [ 0.00926221,  0.00658568,  0.02926275, ...,  0.01882035,
#                      0.0037506 ,  0.02940242]], dtype=float32)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 16,777,216 (67.1 MB)
#             type=Param,
#             value=Array([[ 0.0271954 , -0.02289143,  0.00616923, ..., -0.02619795,
#                      0.00651373, -0.00147831],
#                    [ 0.02185303,  0.03810124,  0.01553211, ...,  0.0321742 ,
#                      0.03555113, -0.00697863],
#                    [ 0.01138093, -0.01883678,  0.00721168, ...,  0.00095089,
#                     -0.00489563, -0.01227289],
#                    ...,
#                    [-0.01227151,  0.03743096,  0.0044958 , ...,  0.02022393,
#                      0.04140033,  0.00451834],
#                    [-0.00732872, -0.01286003,  0.01032387, ...,  0.04457448,
#                      0.01471637,  0.01659669],
#                    [ 0.0226088 , -0.01048542,  0.00813642, ...,  0.00596853,
#                     -0.01597153,  0.00251088]], dtype=float32)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 16,777,216 (67.1 MB)
#             type=Param,
#             value=Array([[-0.00075035, -0.01673108, -0.01056993, ...,  0.00158684,
#                     -0.00479864, -0.00230472],
#                    [ 0.01868046, -0.0156159 , -0.00660762, ...,  0.0009686 ,
#                     -0.00577003,  0.01415168],
#                    [ 0.01139745, -0.00905232,  0.00395795, ..., -0.00263135,
#                      0.01405303,  0.01016581],
#                    ...,
#                    [ 0.00881264, -0.01279651,  0.00921288, ...,  0.00452644,
#                      0.0046311 ,  0.00246387],
#                    [-0.00451448, -0.02119439, -0.01142809, ..., -0.00172945,
#                      0.01418102, -0.0104082 ],
#                    [-0.00279075,  0.01620773,  0.00157642, ...,  0.00229581,
#                     -0.00506593,  0.00156097]], dtype=float32)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 2,048 (8.2 KB)
#           type=Param,
#           value=Array([1., 1., 1., ..., 1., 1., 1.], dtype=float32)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 2,048 (8.2 KB)
#           type=Param,
#           value=Array([1., 1., 1., ..., 1., 1., 1.], dtype=float32)
#         )
#       }
#     },
#     1: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1,048,576 (4.2 MB)
#             type=Param,
#             value=Array([[ 0.00228064, -0.00104312,  0.00112492, ..., -0.02777813,
#                     -0.00938387, -0.01534556],
#                    [ 0.01202171, -0.02776407, -0.00868222, ...,  0.03645394,
#                     -0.03641644, -0.00920523],
#                    [ 0.00586328,  0.00917646, -0.03507987, ...,  0.02664929,
#                     -0.03072914,  0.00878512],
#                    ...,
#                    [ 0.00343442,  0.01803162, -0.01201412, ...,  0.04817232,
#                     -0.00674597,  0.00186378],
#                    [-0.02113312,  0.04402419,  0.00187158, ...,  0.03986165,
#                     -0.01375687, -0.03523852],
#                    [ 0.01569625,  0.02948482, -0.01487958, ..., -0.00245725,
#                      0.03956825, -0.04331922]], dtype=float32)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 4,194,304 (16.8 MB)
#             type=Param,
#             value=Array([[-4.6206964e-03, -9.4984788e-03,  3.3651602e-02, ...,
#                     -1.8771328e-02,  7.5842091e-03, -1.9201175e-03],
#                    [ 5.1961355e-03, -1.6815200e-02,  2.1273983e-03, ...,
#                     -2.1269146e-02, -2.7858732e-02, -2.2218630e-03],
#                    [ 1.3466250e-02,  2.4705967e-02, -9.5654349e-04, ...,
#                      2.0127490e-02,  1.4793766e-02,  1.3985433e-02],
#                    ...,
#                    [ 2.5854085e-02,  2.8520076e-02,  6.4681529e-04, ...,
#                     -3.6780965e-02, -7.7640973e-03, -1.5174907e-03],
#                    [ 2.5367139e-02, -2.2769654e-02,  4.1660338e-04, ...,
#                     -7.8909742e-03, -8.1838160e-05,  1.2041193e-02],
#                    [ 2.9079590e-02, -1.0528611e-02, -1.5604967e-02, ...,
#                      2.5774319e-02,  1.5844226e-02,  1.1770497e-02]], dtype=float32)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1,048,576 (4.2 MB)
#             type=Param,
#             value=Array([[-0.01227002, -0.00080713,  0.03017406, ..., -0.02154619,
#                     -0.02260245, -0.04640712],
#                    [-0.01074179, -0.02677475,  0.01021558, ...,  0.00830661,
#                     -0.00678554,  0.00065738],
#                    [ 0.02851492, -0.00983   , -0.02298431, ..., -0.03644741,
#                      0.02194092,  0.03232972],
#                    ...,
#                    [-0.02896225, -0.01200467, -0.04992149, ..., -0.0101937 ,
#                      0.009312  ,  0.02934805],
#                    [-0.02319529,  0.01904695,  0.01963326, ..., -0.03203527,
#                     -0.04623997,  0.02589992],
#                    [ 0.00377315, -0.01565291, -0.02337384, ...,  0.01948613,
#                      0.01444733, -0.00356267]], dtype=float32)
#           )
#         },
#         'cos': Array([[1, 1, 1, ..., 1, 1, 1],
#                [0.539062, 0.75, 0.867188, ..., 1, 1, 1],
#                [-0.416016, 0.123047, 0.5, ..., 1, 1, 1],
#                ...,
#                [-0.425781, 0.515625, -0.980469, ..., 1, 1, 1],
#                [-0.992188, -0.178711, -0.75, ..., 1, 1, 1],
#                [-0.644531, -0.785156, -0.318359, ..., 1, 1, 1]], dtype=bfloat16),
#         'out_proj': {
#           'kernel': VariableState( # 4,194,304 (16.8 MB)
#             type=Param,
#             value=Array([[-0.01373713,  0.03151745,  0.00675358, ...,  0.01206644,
#                     -0.04857918,  0.02105491],
#                    [-0.0248863 ,  0.00073092, -0.03537469, ..., -0.02517959,
#                      0.02794337,  0.01432092],
#                    [-0.01382349, -0.04272693, -0.03456062, ...,  0.03038181,
#                     -0.0125651 ,  0.0148895 ],
#                    ...,
#                    [ 0.02422843, -0.03515932,  0.02559295, ..., -0.02979263,
#                      0.00427413, -0.0029532 ],
#                    [ 0.04008927, -0.03283432, -0.00854979, ...,  0.00857579,
#                     -0.0045618 , -0.00731834],
#                    [-0.020344  , -0.0352453 , -0.03410161, ..., -0.0307614 ,
#                     -0.01608762,  0.02815981]], dtype=float32)
#           )
#         },
#         'sin': Array([[0, 0, 0, ..., 0, 0, 0],
#                [0.839844, 0.664062, 0.5, ..., 2.63751e-06, 1.90735e-06,
#                 1.37836e-06],
#                [0.910156, 0.992188, 0.867188, ..., 5.27501e-06, 3.8147e-06,
#                 2.75671e-06],
#                ...,
#                [0.90625, 0.855469, -0.198242, ..., 0.0216064, 0.015625,
#                 0.0112915],
#                [0.131836, 0.984375, -0.660156, ..., 0.0216064, 0.015625,
#                 0.0112915],
#                [-0.761719, 0.617188, -0.949219, ..., 0.0216064, 0.015625,
#                 0.0112915]], dtype=bfloat16)
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 16,777,216 (67.1 MB)
#             type=Param,
#             value=Array([[-0.02213784, -0.04131884, -0.00261215, ..., -0.00168023,
#                      0.01785981, -0.01471161],
#                    [-0.04123322,  0.04257102,  0.02845677, ..., -0.00410466,
#                      0.00834341, -0.03808706],
#                    [-0.01876054, -0.00206534,  0.0240449 , ...,  0.02155692,
#                     -0.00455074,  0.00178283],
#                    ...,
#                    [ 0.01286808,  0.0192664 ,  0.00332143, ...,  0.01360519,
#                     -0.021493  , -0.01013261],
#                    [ 0.00953175,  0.03076905,  0.04352533, ...,  0.01247979,
#                      0.00195771,  0.00313062],
#                    [ 0.00296482, -0.02083483, -0.00484289, ...,  0.02052248,
#                     -0.00089592, -0.01925897]], dtype=float32)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 16,777,216 (67.1 MB)
#             type=Param,
#             value=Array([[ 0.00700665, -0.0050619 ,  0.00980019, ..., -0.00244726,
#                     -0.0026035 , -0.00134519],
#                    [-0.03903614,  0.0446891 , -0.01753616, ..., -0.00342566,
#                      0.04093153,  0.02648025],
#                    [-0.02557437, -0.04871934, -0.01589461, ...,  0.00786518,
#                     -0.02699018,  0.00137552],
#                    ...,
#                    [-0.02115372,  0.01713058,  0.00897623, ..., -0.02542932,
#                     -0.01127488,  0.01456694],
#                    [-0.01504254,  0.03181472,  0.02750095, ..., -0.03267531,
#                     -0.00403792, -0.02606246],
#                    [ 0.01936783,  0.0022676 ,  0.01840491, ..., -0.02352269,
#                     -0.01535558, -0.00094116]], dtype=float32)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 16,777,216 (67.1 MB)
#             type=Param,
#             value=Array([[-0.01169845, -0.00744526, -0.02120277, ...,  0.00686768,
#                      0.00574747, -0.01850328],
#                    [-0.00871836,  0.01926425,  0.00406777, ...,  0.00158425,
#                      0.01893946, -0.00334497],
#                    [ 0.00149646, -0.00951793,  0.00869341, ...,  0.01440629,
#                     -0.00974861, -0.01186184],
#                    ...,
#                    [ 0.01135334, -0.01214804, -0.02079952, ..., -0.02126169,
#                      0.01621513, -0.00965978],
#                    [ 0.00128358, -0.0004651 ,  0.00528729, ...,  0.01493016,
#                     -0.01597754, -0.00558533],
#                    [ 0.00618093, -0.00524051, -0.00910164, ...,  0.00953971,
#                      0.0160243 , -0.0005164 ]], dtype=float32)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 2,048 (8.2 KB)
#           type=Param,
#           value=Array([1., 1., 1., ..., 1., 1., 1.], dtype=float32)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 2,048 (8.2 KB)
#           type=Param,
#           value=Array([1., 1., 1., ..., 1., 1., 1.], dtype=float32)
#         )
#       }
#     },
#     2: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1,048,576 (4.2 MB)
#             type=Param,
#             value=Array([[-0.00994353, -0.00072937,  0.01255292, ...,  0.02004664,
#                     -0.03016157, -0.0228302 ],
#                    [-0.03255835,  0.02484188, -0.02189162, ...,  0.0077448 ,
#                     -0.01685358, -0.00779321],
#                    [ 0.00884178,  0.03611119,  0.04312639, ..., -0.00408583,
#                     -0.02349306, -0.02123083],
#                    ...,
#                    [-0.01246114,  0.04281598,  0.00568872, ..., -0.02927464,
#                      0.01880288,  0.00688381],
#                    [-0.00636433,  0.0364911 , -0.00831384, ..., -0.01466339,
#                     -0.01438999,  0.01602843],
#                    [ 0.03804455,  0.00790613,  0.00831251, ..., -0.01403097,
#                      0.01859831,  0.0016362 ]], dtype=float32)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 4,194,304 (16.8 MB)
#             type=Param,
#             value=Array([[-0.00469834,  0.01578214,  0.02447357, ..., -0.01086385,
#                      0.00072767,  0.03461938],
#                    [-0.01562212, -0.01040315, -0.00622929, ..., -0.03651557,
#                     -0.00628321, -0.00591227],
#                    [ 0.0069474 ,  0.01534779, -0.02745056, ...,  0.02464391,
#                     -0.01630227,  0.02097023],
#                    ...,
#                    [ 0.01463717, -0.01395168,  0.01821869, ...,  0.03081131,
#                      0.00678702,  0.01263301],
#                    [-0.00342268, -0.03408333, -0.03643158, ..., -0.01014698,
#                     -0.00378904,  0.00238357],
#                    [-0.01338799, -0.00491192,  0.00793594, ...,  0.00951104,
#                     -0.00065871, -0.01141587]], dtype=float32)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1,048,576 (4.2 MB)
#             type=Param,
#             value=Array([[-0.00203867, -0.00131114, -0.00579908, ..., -0.00139064,
#                      0.03091006, -0.01992687],
#                    [-0.02968533, -0.00723371,  0.01475424, ...,  0.01254192,
#                      0.03984894, -0.01917642],
#                    [ 0.02327834,  0.03850887,  0.00015277, ..., -0.01867591,
#                      0.0033543 ,  0.01088547],
#                    ...,
#                    [ 0.0151041 , -0.0002847 ,  0.00634791, ...,  0.02630067,
#                      0.00840583, -0.0103466 ],
#                    [-0.02025531,  0.03657556,  0.02227258, ..., -0.00984845,
#                     -0.04604798,  0.02088973],
#                    [ 0.00721833,  0.04889201, -0.02307006, ...,  0.01146614,
#                     -0.03259675, -0.01839002]], dtype=float32)
#           )
#         },
#         'cos': Array([[1, 1, 1, ..., 1, 1, 1],
#                [0.539062, 0.75, 0.867188, ..., 1, 1, 1],
#                [-0.416016, 0.123047, 0.5, ..., 1, 1, 1],
#                ...,
#                [-0.425781, 0.515625, -0.980469, ..., 1, 1, 1],
#                [-0.992188, -0.178711, -0.75, ..., 1, 1, 1],
#                [-0.644531, -0.785156, -0.318359, ..., 1, 1, 1]], dtype=bfloat16),
#         'out_proj': {
#           'kernel': VariableState( # 4,194,304 (16.8 MB)
#             type=Param,
#             value=Array([[ 0.02986111,  0.01847402, -0.03221343, ..., -0.00446875,
#                     -0.02018891,  0.00962652],
#                    [-0.02234169, -0.00303905,  0.0302713 , ..., -0.01570672,
#                     -0.01406977, -0.02461554],
#                    [ 0.00541519, -0.03045509,  0.013728  , ...,  0.02221015,
#                     -0.04167854, -0.01092544],
#                    ...,
#                    [ 0.0222437 , -0.02546964,  0.00108666, ..., -0.02987316,
#                      0.00538645,  0.01779038],
#                    [ 0.04078724, -0.00327095,  0.01342283, ..., -0.00531045,
#                      0.02643252,  0.00227284],
#                    [-0.00284389, -0.00071614,  0.01730477, ..., -0.00652746,
#                     -0.03400156, -0.03317751]], dtype=float32)
#           )
#         },
#         'sin': Array([[0, 0, 0, ..., 0, 0, 0],
#                [0.839844, 0.664062, 0.5, ..., 2.63751e-06, 1.90735e-06,
#                 1.37836e-06],
#                [0.910156, 0.992188, 0.867188, ..., 5.27501e-06, 3.8147e-06,
#                 2.75671e-06],
#                ...,
#                [0.90625, 0.855469, -0.198242, ..., 0.0216064, 0.015625,
#                 0.0112915],
#                [0.131836, 0.984375, -0.660156, ..., 0.0216064, 0.015625,
#                 0.0112915],
#                [-0.761719, 0.617188, -0.949219, ..., 0.0216064, 0.015625,
#                 0.0112915]], dtype=bfloat16)
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 16,777,216 (67.1 MB)
#             type=Param,
#             value=Array([[ 0.03951761, -0.01687813,  0.02229478, ...,  0.00307228,
#                     -0.01716676, -0.00350976],
#                    [ 0.00189739, -0.00964978, -0.0058798 , ...,  0.01347287,
#                     -0.0218403 ,  0.01879827],
#                    [ 0.00771861,  0.00765173,  0.01532121, ...,  0.01655059,
#                      0.04026011, -0.03996787],
#                    ...,
#                    [ 0.00667872,  0.00952633,  0.0068796 , ...,  0.00592127,
#                      0.03260983,  0.01041497],
#                    [ 0.02435621, -0.01592425,  0.04259576, ...,  0.02457695,
#                      0.0217676 ,  0.01770344],
#                    [-0.00376279, -0.02604578,  0.00305808, ..., -0.0043394 ,
#                      0.00328246,  0.02413502]], dtype=float32)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 16,777,216 (67.1 MB)
#             type=Param,
#             value=Array([[-0.00354339,  0.01951275,  0.01822811, ..., -0.01091143,
#                      0.03340342, -0.01412184],
#                    [-0.02447491,  0.03242473,  0.00232807, ...,  0.01362662,
#                      0.01656996, -0.00055251],
#                    [-0.00152683, -0.01667125,  0.00988737, ..., -0.00600061,
#                      0.02212947, -0.04423618],
#                    ...,
#                    [ 0.01224237,  0.00154608,  0.0265935 , ...,  0.00909267,
#                     -0.01652677,  0.04103515],
#                    [-0.02601048,  0.00253629,  0.01301379, ..., -0.00622994,
#                     -0.01224621,  0.04560839],
#                    [ 0.00741344,  0.02427763, -0.01409767, ...,  0.02809497,
#                     -0.02744949, -0.02547158]], dtype=float32)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 16,777,216 (67.1 MB)
#             type=Param,
#             value=Array([[-0.01128889, -0.0055089 ,  0.00741816, ...,  0.02046851,
#                     -0.0082677 , -0.01173709],
#                    [ 0.01531314, -0.00699876,  0.01928517, ..., -0.01298727,
#                      0.00900685,  0.02140936],
#                    [-0.00774685, -0.00247177, -0.00462338, ..., -0.00812229,
#                     -0.00031148, -0.00485715],
#                    ...,
#                    [-0.00417892,  0.01653046, -0.01102378, ...,  0.01702427,
#                     -0.01761086,  0.00696491],
#                    [ 0.0098043 ,  0.01587362, -0.006553  , ...,  0.00768208,
#                      0.00986526,  0.00097981],
#                    [ 0.00746076,  0.01392084,  0.00202498, ...,  0.00401177,
#                     -0.01146493,  0.00738248]], dtype=float32)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 2,048 (8.2 KB)
#           type=Param,
#           value=Array([1., 1., 1., ..., 1., 1., 1.], dtype=float32)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 2,048 (8.2 KB)
#           type=Param,
#           value=Array([1., 1., 1., ..., 1., 1., 1.], dtype=float32)
#         )
#       }
#     },
#     3: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1,048,576 (4.2 MB)
#             type=Param,
#             value=Array([[-0.02089896,  0.02886079, -0.03560195, ...,  0.00544937,
#                     -0.00712273, -0.02034459],
#                    [-0.02384639,  0.04170847, -0.0108511 , ...,  0.02791587,
#                      0.04550699,  0.00808736],
#                    [-0.01166316, -0.02572115, -0.00932019, ...,  0.00278895,
#                     -0.04758683, -0.00279662],
#                    ...,
#                    [-0.00453194, -0.0128956 ,  0.01347825, ..., -0.03559618,
#                     -0.0208527 ,  0.02714936],
#                    [-0.04647703, -0.01068522,  0.01526728, ..., -0.0020636 ,
#                     -0.01603057,  0.03235374],
#                    [-0.01396141, -0.0111054 ,  0.0107063 , ...,  0.01014119,
#                     -0.00505109, -0.03220489]], dtype=float32)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 4,194,304 (16.8 MB)
#             type=Param,
#             value=Array([[ 1.6160052e-02,  1.4261960e-03,  1.8383507e-02, ...,
#                     -2.5145136e-02, -1.9625314e-03,  1.2428389e-02],
#                    [ 1.9974289e-02,  5.2666175e-03,  2.9552370e-02, ...,
#                     -1.9496489e-02,  1.1419157e-02, -2.5467945e-02],
#                    [-1.9095020e-02, -2.8913757e-02,  2.1018224e-02, ...,
#                     -3.4747779e-02, -4.0040709e-02, -3.0897181e-02],
#                    ...,
#                    [-7.7589648e-03,  1.2922526e-02, -1.1134547e-02, ...,
#                      3.2161187e-02,  4.2987037e-02,  5.3490354e-03],
#                    [ 2.4464402e-02,  5.2741205e-05, -2.3310671e-02, ...,
#                      1.4494891e-02, -2.2060992e-02,  6.1510182e-03],
#                    [ 1.0853689e-02, -8.3912835e-03, -2.3830455e-02, ...,
#                     -4.2686477e-02, -3.8604103e-02,  1.7357115e-02]], dtype=float32)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1,048,576 (4.2 MB)
#             type=Param,
#             value=Array([[-0.01178146,  0.00729331,  0.01499635, ..., -0.02170738,
#                      0.0137067 ,  0.04022959],
#                    [-0.0440939 , -0.01034798, -0.03799122, ..., -0.022677  ,
#                     -0.03515645, -0.0228562 ],
#                    [ 0.00125415, -0.00911703,  0.01548911, ...,  0.04560675,
#                      0.0013979 ,  0.03920854],
#                    ...,
#                    [-0.00016332, -0.02159647,  0.02957706, ..., -0.03705365,
#                     -0.00402182,  0.00820796],
#                    [-0.01810555, -0.01278295,  0.01189213, ..., -0.01316205,
#                     -0.01672001,  0.02013431],
#                    [ 0.03028348,  0.02236402,  0.00247709, ...,  0.01447196,
#                     -0.01647096, -0.01293159]], dtype=float32)
#           )
#         },
#         'cos': Array([[1, 1, 1, ..., 1, 1, 1],
#                [0.539062, 0.75, 0.867188, ..., 1, 1, 1],
#                [-0.416016, 0.123047, 0.5, ..., 1, 1, 1],
#                ...,
#                [-0.425781, 0.515625, -0.980469, ..., 1, 1, 1],
#                [-0.992188, -0.178711, -0.75, ..., 1, 1, 1],
#                [-0.644531, -0.785156, -0.318359, ..., 1, 1, 1]], dtype=bfloat16),
#         'out_proj': {
#           'kernel': VariableState( # 4,194,304 (16.8 MB)
#             type=Param,
#             value=Array([[-0.04682016,  0.02038978,  0.00023804, ..., -0.01692219,
#                     -0.01233708, -0.0358615 ],
#                    [-0.00960326,  0.01269799, -0.0385445 , ...,  0.01846715,
#                      0.01423299, -0.01499766],
#                    [ 0.00024448, -0.02240475, -0.00954046, ..., -0.01348752,
#                      0.02683916,  0.03900451],
#                    ...,
#                    [-0.02377049, -0.01006448, -0.02226305, ..., -0.03376822,
#                      0.00288392, -0.01461037],
#                    [-0.00375936,  0.03325999, -0.02448981, ...,  0.01782597,
#                      0.0367429 ,  0.00066541],
#                    [ 0.00561786,  0.00014311,  0.00254921, ...,  0.00752841,
#                     -0.00701   , -0.0282586 ]], dtype=float32)
#           )
#         },
#         'sin': Array([[0, 0, 0, ..., 0, 0, 0],
#                [0.839844, 0.664062, 0.5, ..., 2.63751e-06, 1.90735e-06,
#                 1.37836e-06],
#                [0.910156, 0.992188, 0.867188, ..., 5.27501e-06, 3.8147e-06,
#                 2.75671e-06],
#                ...,
#                [0.90625, 0.855469, -0.198242, ..., 0.0216064, 0.015625,
#                 0.0112915],
#                [0.131836, 0.984375, -0.660156, ..., 0.0216064, 0.015625,
#                 0.0112915],
#                [-0.761719, 0.617188, -0.949219, ..., 0.0216064, 0.015625,
#                 0.0112915]], dtype=bfloat16)
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 16,777,216 (67.1 MB)
#             type=Param,
#             value=Array([[ 0.00891892, -0.01463561,  0.00027536, ...,  0.02831835,
#                      0.02984096,  0.03949722],
#                    [-0.01473185, -0.00907007,  0.00592282, ...,  0.03083296,
#                     -0.02284281, -0.00344224],
#                    [-0.03884089, -0.00402241, -0.00769967, ...,  0.02352287,
#                      0.002968  ,  0.01234469],
#                    ...,
#                    [ 0.00513914,  0.0227854 , -0.01175965, ..., -0.0228225 ,
#                      0.03242619, -0.00771128],
#                    [-0.00928065, -0.03593302, -0.02431975, ...,  0.00163084,
#                      0.01933161,  0.01248881],
#                    [-0.02221002, -0.02766605, -0.00326152, ...,  0.0319685 ,
#                     -0.04680987,  0.02227104]], dtype=float32)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 16,777,216 (67.1 MB)
#             type=Param,
#             value=Array([[-0.00956571,  0.03910971,  0.0126518 , ...,  0.03458137,
#                      0.00098712,  0.03135405],
#                    [-0.00088953, -0.01712517, -0.01459378, ...,  0.02055588,
#                     -0.01256877,  0.01437257],
#                    [ 0.00338022,  0.01647266,  0.03294651, ...,  0.02699258,
#                      0.0177523 , -0.03797778],
#                    ...,
#                    [-0.03224303, -0.0276276 , -0.0446734 , ...,  0.00689309,
#                      0.00503604, -0.0284663 ],
#                    [-0.01402701, -0.02719203, -0.00916583, ..., -0.01331076,
#                     -0.01551247, -0.03680626],
#                    [-0.03169604, -0.02780048,  0.00253051, ..., -0.02298401,
#                      0.00952861,  0.01174132]], dtype=float32)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 16,777,216 (67.1 MB)
#             type=Param,
#             value=Array([[-0.00513348, -0.01452246, -0.00418656, ..., -0.00090107,
#                     -0.0062561 ,  0.01124378],
#                    [ 0.00718023,  0.0117939 ,  0.00118274, ..., -0.01112311,
#                     -0.00242573, -0.02192537],
#                    [ 0.0056385 ,  0.01496749, -0.02021663, ..., -0.0057103 ,
#                      0.00799303, -0.00608957],
#                    ...,
#                    [-0.01084234, -0.00507298, -0.01760465, ..., -0.00412882,
#                      0.01016441, -0.0055149 ],
#                    [-0.01560221, -0.00990437, -0.01616432, ...,  0.0007699 ,
#                      0.00080008, -0.00311321],
#                    [ 0.0037166 , -0.01597352,  0.00228366, ...,  0.00496152,
#                      0.00898815, -0.0028329 ]], dtype=float32)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 2,048 (8.2 KB)
#           type=Param,
#           value=Array([1., 1., 1., ..., 1., 1., 1.], dtype=float32)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 2,048 (8.2 KB)
#           type=Param,
#           value=Array([1., 1., 1., ..., 1., 1., 1.], dtype=float32)
#         )
#       }
#     },
#     4: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1,048,576 (4.2 MB)
#             type=Param,
#             value=Array([[-0.03085344,  0.00505302, -0.02361738, ..., -0.02426686,
#                      0.02987794, -0.00023845],
#                    [-0.02533613,  0.00703369, -0.02398757, ..., -0.02704221,
#                     -0.01388009, -0.01700242],
#                    [ 0.00945729,  0.01645439,  0.01111221, ...,  0.04883553,
#                      0.03567755,  0.04794227],
#                    ...,
#                    [-0.01649314,  0.01066556, -0.02668925, ...,  0.02221541,
#                      0.00587784,  0.00017244],
#                    [-0.00109931,  0.00284165, -0.01222152, ..., -0.00285815,
#                      0.02552263, -0.0103896 ],
#                    [ 0.01506115,  0.01428278, -0.04359806, ...,  0.01285946,
#                      0.00841793,  0.03269375]], dtype=float32)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 4,194,304 (16.8 MB)
#             type=Param,
#             value=Array([[ 0.00087694, -0.0040787 ,  0.01494312, ..., -0.01586688,
#                     -0.01328037, -0.00044938],
#                    [-0.04941415, -0.02754553,  0.01178802, ..., -0.04144097,
#                      0.00219734, -0.01756868],
#                    [-0.02331301, -0.00393024, -0.01070675, ...,  0.00651444,
#                     -0.03189482,  0.01875474],
#                    ...,
#                    [ 0.00860182, -0.00068109, -0.02560844, ..., -0.03785127,
#                     -0.00622321, -0.01433976],
#                    [-0.00588802, -0.02016932,  0.00561367, ..., -0.00699548,
#                      0.01874635, -0.01633396],
#                    [-0.0138951 ,  0.02246541, -0.01798044, ...,  0.03624142,
#                      0.02008483,  0.04605972]], dtype=float32)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1,048,576 (4.2 MB)
#             type=Param,
#             value=Array([[ 0.01366981, -0.03482491, -0.01617565, ..., -0.0171421 ,
#                      0.01978208,  0.01003788],
#                    [-0.0087367 , -0.00906666, -0.01316522, ...,  0.02410772,
#                     -0.01000233,  0.01972984],
#                    [ 0.00037751, -0.01430669,  0.02060427, ...,  0.00065019,
#                      0.00115474, -0.00129314],
#                    ...,
#                    [ 0.00628897,  0.01512459, -0.00783744, ..., -0.01170017,
#                      0.01674997, -0.0016215 ],
#                    [ 0.02363652,  0.03026858,  0.04372854, ..., -0.00487618,
#                     -0.01280552,  0.00599979],
#                    [ 0.02448043,  0.0034687 ,  0.04083778, ...,  0.03008133,
#                      0.01871992,  0.02187628]], dtype=float32)
#           )
#         },
#         'cos': Array([[1, 1, 1, ..., 1, 1, 1],
#                [0.539062, 0.75, 0.867188, ..., 1, 1, 1],
#                [-0.416016, 0.123047, 0.5, ..., 1, 1, 1],
#                ...,
#                [-0.425781, 0.515625, -0.980469, ..., 1, 1, 1],
#                [-0.992188, -0.178711, -0.75, ..., 1, 1, 1],
#                [-0.644531, -0.785156, -0.318359, ..., 1, 1, 1]], dtype=bfloat16),
#         'out_proj': {
#           'kernel': VariableState( # 4,194,304 (16.8 MB)
#             type=Param,
#             value=Array([[ 0.02734115, -0.01226835,  0.00462771, ...,  0.03081806,
#                     -0.01852442, -0.02670415],
#                    [ 0.02872033,  0.04882221, -0.00472246, ...,  0.01088352,
#                      0.01845909, -0.02727234],
#                    [-0.02958043, -0.02533161, -0.02028883, ...,  0.01111533,
#                      0.01091478, -0.03405846],
#                    ...,
#                    [ 0.02084305,  0.03067262,  0.01081886, ...,  0.03743922,
#                      0.04808282, -0.01232881],
#                    [-0.01023847,  0.01590437,  0.02485658, ..., -0.01406758,
#                     -0.04589894,  0.01947622],
#                    [ 0.00039012,  0.00588612,  0.0316474 , ..., -0.00720206,
#                      0.0220358 ,  0.00236467]], dtype=float32)
#           )
#         },
#         'sin': Array([[0, 0, 0, ..., 0, 0, 0],
#                [0.839844, 0.664062, 0.5, ..., 2.63751e-06, 1.90735e-06,
#                 1.37836e-06],
#                [0.910156, 0.992188, 0.867188, ..., 5.27501e-06, 3.8147e-06,
#                 2.75671e-06],
#                ...,
#                [0.90625, 0.855469, -0.198242, ..., 0.0216064, 0.015625,
#                 0.0112915],
#                [0.131836, 0.984375, -0.660156, ..., 0.0216064, 0.015625,
#                 0.0112915],
#                [-0.761719, 0.617188, -0.949219, ..., 0.0216064, 0.015625,
#                 0.0112915]], dtype=bfloat16)
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 16,777,216 (67.1 MB)
#             type=Param,
#             value=Array([[ 0.01783256,  0.01655504, -0.01459789, ...,  0.04529827,
#                      0.03455136, -0.02880705],
#                    [-0.00893854,  0.03403686,  0.02667492, ..., -0.00148693,
#                      0.02236505, -0.011886  ],
#                    [ 0.04567704,  0.01992621,  0.02382291, ..., -0.02384263,
#                      0.00567258, -0.00220659],
#                    ...,
#                    [-0.01360429,  0.00210092,  0.03578926, ...,  0.02913181,
#                      0.01162715,  0.04053704],
#                    [-0.03160829, -0.00678406,  0.04143023, ..., -0.00356596,
#                      0.01149091, -0.00594513],
#                    [-0.01404653,  0.01475229, -0.00025312, ..., -0.02145236,
#                      0.00181726,  0.04742655]], dtype=float32)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 16,777,216 (67.1 MB)
#             type=Param,
#             value=Array([[-0.00037495, -0.00671871, -0.00140704, ..., -0.00736397,
#                     -0.02975116, -0.04038189],
#                    [-0.0188608 , -0.00444701, -0.00457043, ...,  0.03615046,
#                     -0.02421319,  0.01860658],
#                    [ 0.04282613,  0.03536804,  0.00479572, ...,  0.02873688,
#                      0.00573027,  0.00802863],
#                    ...,
#                    [-0.00934938, -0.03557117, -0.00249698, ...,  0.04662256,
#                     -0.00137089,  0.00409741],
#                    [-0.03930467,  0.01892018, -0.00085144, ..., -0.00343745,
#                     -0.00673013, -0.01147893],
#                    [-0.00146934, -0.00636631, -0.01438046, ...,  0.00645259,
#                      0.00642239, -0.00613838]], dtype=float32)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 16,777,216 (67.1 MB)
#             type=Param,
#             value=Array([[ 0.01235803,  0.01028867,  0.00741037, ...,  0.00585569,
#                     -0.01182815, -0.00665125],
#                    [-0.02460667,  0.01526838,  0.01256814, ..., -0.01381566,
#                      0.00198771,  0.01303102],
#                    [-0.01203827, -0.00602725, -0.01033027, ...,  0.01448334,
#                      0.00851541,  0.00779182],
#                    ...,
#                    [-0.00503245, -0.01178939, -0.00423544, ...,  0.00146657,
#                      0.00924199, -0.00911584],
#                    [-0.02125926,  0.00656917,  0.00526643, ..., -0.00137525,
#                     -0.01374301,  0.00072639],
#                    [ 0.02187856,  0.016561  ,  0.00840593, ...,  0.00789716,
#                     -0.00502226,  0.0009754 ]], dtype=float32)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 2,048 (8.2 KB)
#           type=Param,
#           value=Array([1., 1., 1., ..., 1., 1., 1.], dtype=float32)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 2,048 (8.2 KB)
#           type=Param,
#           value=Array([1., 1., 1., ..., 1., 1., 1.], dtype=float32)
#         )
#       }
#     },
#     5: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1,048,576 (4.2 MB)
#             type=Param,
#             value=Array([[-0.03907693,  0.00724175, -0.04231874, ..., -0.03322196,
#                      0.00179926,  0.02090834],
#                    [ 0.01207314, -0.00966576,  0.00087753, ..., -0.00603176,
#                      0.03328484,  0.01767104],
#                    [ 0.02052905, -0.01893814, -0.00317897, ...,  0.02398675,
#                      0.00089366, -0.01627886],
#                    ...,
#                    [-0.00582043, -0.02670234, -0.00835355, ..., -0.02697937,
#                     -0.02898144,  0.00262245],
#                    [ 0.03357694, -0.02121976, -0.01333028, ...,  0.01375312,
#                      0.04413106, -0.01414614],
#                    [-0.01885752,  0.01102338,  0.01667315, ..., -0.00662142,
#                     -0.02566897,  0.00810755]], dtype=float32)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 4,194,304 (16.8 MB)
#             type=Param,
#             value=Array([[ 0.01202336,  0.00404166,  0.04758468, ..., -0.00659909,
#                     -0.00066528,  0.04599411],
#                    [-0.0452907 ,  0.03747457,  0.02276208, ...,  0.02178168,
#                     -0.00911415, -0.04303072],
#                    [-0.03708944, -0.01797756, -0.00495037, ..., -0.00782469,
#                     -0.0047572 ,  0.01982618],
#                    ...,
#                    [-0.01689839,  0.00328898, -0.00342261, ...,  0.01531623,
#                     -0.01625214, -0.01579151],
#                    [-0.02593237,  0.03402658, -0.00912166, ..., -0.01672675,
#                      0.04329408,  0.00899961],
#                    [ 0.00176673,  0.02053709, -0.0229227 , ...,  0.0056219 ,
#                     -0.01275886,  0.01771217]], dtype=float32)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1,048,576 (4.2 MB)
#             type=Param,
#             value=Array([[-0.00842844,  0.01342301, -0.00543361, ...,  0.01584666,
#                      0.01815436, -0.00090138],
#                    [ 0.00905541,  0.0250604 ,  0.02403841, ...,  0.02503483,
#                     -0.02038248, -0.01510777],
#                    [-0.00344518,  0.02281059,  0.010299  , ...,  0.02522114,
#                      0.0072377 ,  0.02021285],
#                    ...,
#                    [ 0.01020018, -0.02655543, -0.00309425, ...,  0.01195718,
#                     -0.04691187,  0.02660148],
#                    [-0.02720845, -0.00318971,  0.03054013, ..., -0.01935765,
#                     -0.0291606 ,  0.0345506 ],
#                    [ 0.01903493,  0.02690429, -0.00425094, ..., -0.03116535,
#                      0.01876736,  0.003605  ]], dtype=float32)
#           )
#         },
#         'cos': Array([[1, 1, 1, ..., 1, 1, 1],
#                [0.539062, 0.75, 0.867188, ..., 1, 1, 1],
#                [-0.416016, 0.123047, 0.5, ..., 1, 1, 1],
#                ...,
#                [-0.425781, 0.515625, -0.980469, ..., 1, 1, 1],
#                [-0.992188, -0.178711, -0.75, ..., 1, 1, 1],
#                [-0.644531, -0.785156, -0.318359, ..., 1, 1, 1]], dtype=bfloat16),
#         'out_proj': {
#           'kernel': VariableState( # 4,194,304 (16.8 MB)
#             type=Param,
#             value=Array([[-2.2737766e-02,  1.9814262e-02, -1.5607810e-02, ...,
#                     -2.4014732e-03,  2.9117761e-02,  1.7675918e-02],
#                    [-3.4114473e-02, -3.5275079e-02,  6.1623747e-03, ...,
#                     -2.6931081e-02, -3.6215357e-02,  3.3043146e-02],
#                    [-1.3131225e-02, -3.0834263e-02,  4.8228391e-02, ...,
#                      8.2225073e-05, -1.8486561e-02,  2.1711195e-02],
#                    ...,
#                    [-7.9649575e-03, -3.9004923e-03,  3.1648047e-02, ...,
#                      6.9066025e-03, -2.6362648e-03, -1.9993733e-03],
#                    [ 2.4643974e-02, -9.2444262e-03,  2.0173838e-02, ...,
#                     -4.8227705e-02, -1.6478453e-02, -1.5657244e-02],
#                    [ 8.4132422e-03, -2.8348150e-02,  1.1695193e-02, ...,
#                     -7.5514298e-03, -2.6772621e-03, -3.8770869e-02]], dtype=float32)
#           )
#         },
#         'sin': Array([[0, 0, 0, ..., 0, 0, 0],
#                [0.839844, 0.664062, 0.5, ..., 2.63751e-06, 1.90735e-06,
#                 1.37836e-06],
#                [0.910156, 0.992188, 0.867188, ..., 5.27501e-06, 3.8147e-06,
#                 2.75671e-06],
#                ...,
#                [0.90625, 0.855469, -0.198242, ..., 0.0216064, 0.015625,
#                 0.0112915],
#                [0.131836, 0.984375, -0.660156, ..., 0.0216064, 0.015625,
#                 0.0112915],
#                [-0.761719, 0.617188, -0.949219, ..., 0.0216064, 0.015625,
#                 0.0112915]], dtype=bfloat16)
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 16,777,216 (67.1 MB)
#             type=Param,
#             value=Array([[ 0.03049791,  0.00174566,  0.02973224, ...,  0.00339255,
#                      0.04747411,  0.00949667],
#                    [ 0.03887434, -0.03037884, -0.00189596, ..., -0.01067157,
#                     -0.00759605,  0.04610194],
#                    [ 0.04601438,  0.00780932, -0.02063819, ..., -0.03782246,
#                     -0.00721606,  0.02265103],
#                    ...,
#                    [-0.04902974, -0.01945821, -0.01907137, ..., -0.02175567,
#                      0.00276746, -0.03428565],
#                    [ 0.03604119,  0.02645686, -0.00427872, ...,  0.00147969,
#                      0.0004176 ,  0.01976146],
#                    [ 0.02666754,  0.01437727,  0.01031286, ...,  0.0294252 ,
#                     -0.04781692, -0.04081098]], dtype=float32)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 16,777,216 (67.1 MB)
#             type=Param,
#             value=Array([[ 0.00151573, -0.02613869,  0.02188571, ..., -0.01995311,
#                     -0.01775071,  0.00998993],
#                    [ 0.03543924, -0.01235771, -0.02676687, ...,  0.0039927 ,
#                     -0.02029844,  0.01408213],
#                    [ 0.00117653, -0.01350389,  0.01204726, ...,  0.00774339,
#                     -0.00364554,  0.03978225],
#                    ...,
#                    [-0.01681202,  0.02490407,  0.02087216, ...,  0.0130117 ,
#                     -0.02310195, -0.0311352 ],
#                    [-0.03336984,  0.02923252, -0.01447285, ...,  0.01864875,
#                     -0.01296578,  0.033526  ],
#                    [-0.00845143,  0.00496666,  0.00931056, ...,  0.03509699,
#                      0.03390915,  0.02046878]], dtype=float32)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 16,777,216 (67.1 MB)
#             type=Param,
#             value=Array([[ 8.8118073e-03,  4.2136884e-03, -1.1225381e-02, ...,
#                      2.2926325e-02,  6.5040091e-05, -1.0533606e-02],
#                    [ 1.8218504e-02,  7.7583701e-03,  1.3167096e-03, ...,
# ...
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 2,048 (8.2 KB)
#           type=Param,
#           value=Array([1., 1., 1., ..., 1., 1., 1.], dtype=float32)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 2,048 (8.2 KB)
#           type=Param,
#           value=Array([1., 1., 1., ..., 1., 1., 1.], dtype=float32)
#         )
#       }
#     },
#     14: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1,048,576 (4.2 MB)
#             type=Param,
#             value=Array([[ 0.00438079,  0.00738154, -0.0171611 , ...,  0.00942148,
#                     -0.02611083,  0.03245641],
#                    [-0.00415184,  0.02574441,  0.00466021, ...,  0.00531753,
#                      0.03885503, -0.02533968],
#                    [-0.00192189,  0.00980381,  0.00355711, ..., -0.02251531,
#                      0.01608894,  0.02305065],
#                    ...,
#                    [ 0.01001701, -0.00544609, -0.01579481, ...,  0.01649597,
#                      0.00775687, -0.023006  ],
#                    [ 0.03658979, -0.01019766,  0.01495298, ...,  0.00152982,
#                      0.00878473,  0.01488469],
#                    [-0.04368057, -0.01321816,  0.04703341, ...,  0.04563168,
#                      0.00134479, -0.04793497]], dtype=float32)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 4,194,304 (16.8 MB)
#             type=Param,
#             value=Array([[ 0.00682368,  0.00334536, -0.03635063, ...,  0.02580692,
#                      0.00526978,  0.00493576],
#                    [-0.02372921, -0.00343842, -0.03444233, ...,  0.00800909,
#                     -0.04496924, -0.02294857],
#                    [ 0.01873852,  0.0189343 , -0.01607272, ..., -0.01051324,
#                      0.02563537, -0.01539059],
#                    ...,
#                    [-0.00380646, -0.02696995, -0.03640454, ..., -0.00514767,
#                     -0.01861071, -0.00662172],
#                    [ 0.00954066,  0.00487092, -0.01400882, ..., -0.00725718,
#                     -0.02653914,  0.04462371],
#                    [-0.0037202 , -0.00117833,  0.00159745, ...,  0.00604347,
#                     -0.01371676,  0.0066224 ]], dtype=float32)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1,048,576 (4.2 MB)
#             type=Param,
#             value=Array([[-0.01315235,  0.01323511,  0.01792198, ...,  0.02497874,
#                      0.00586509,  0.00330935],
#                    [ 0.04347361,  0.03113711, -0.01387557, ...,  0.00525483,
#                     -0.02138569,  0.03809232],
#                    [ 0.02333907,  0.0167594 , -0.04233458, ..., -0.03659271,
#                      0.01183015, -0.0239114 ],
#                    ...,
#                    [ 0.01621908, -0.00412989, -0.02608078, ..., -0.03370741,
#                     -0.01892048,  0.01217863],
#                    [ 0.04775393,  0.03090521, -0.01883807, ..., -0.02321998,
#                     -0.02872747,  0.00016378],
#                    [-0.00768973, -0.01356907,  0.01263943, ...,  0.01909279,
#                     -0.01301891, -0.00635505]], dtype=float32)
#           )
#         },
#         'cos': Array([[1, 1, 1, ..., 1, 1, 1],
#                [0.539062, 0.75, 0.867188, ..., 1, 1, 1],
#                [-0.416016, 0.123047, 0.5, ..., 1, 1, 1],
#                ...,
#                [-0.425781, 0.515625, -0.980469, ..., 1, 1, 1],
#                [-0.992188, -0.178711, -0.75, ..., 1, 1, 1],
#                [-0.644531, -0.785156, -0.318359, ..., 1, 1, 1]], dtype=bfloat16),
#         'out_proj': {
#           'kernel': VariableState( # 4,194,304 (16.8 MB)
#             type=Param,
#             value=Array([[ 0.0064526 ,  0.00337123,  0.0251762 , ...,  0.04094905,
#                     -0.00947908, -0.01482219],
#                    [ 0.00169835, -0.02764613,  0.03640554, ...,  0.01501975,
#                      0.02637682, -0.02140131],
#                    [ 0.04527975, -0.03957157,  0.00671647, ...,  0.01334326,
#                      0.00983649, -0.00050422],
#                    ...,
#                    [ 0.00270634, -0.02261602,  0.00920888, ...,  0.00770137,
#                     -0.02069386,  0.00156471],
#                    [-0.02537972, -0.0103527 , -0.00399109, ...,  0.0084458 ,
#                     -0.03735811,  0.00032471],
#                    [ 0.03283705,  0.00524705,  0.01616423, ...,  0.00047198,
#                     -0.00774877,  0.02810687]], dtype=float32)
#           )
#         },
#         'sin': Array([[0, 0, 0, ..., 0, 0, 0],
#                [0.839844, 0.664062, 0.5, ..., 2.63751e-06, 1.90735e-06,
#                 1.37836e-06],
#                [0.910156, 0.992188, 0.867188, ..., 5.27501e-06, 3.8147e-06,
#                 2.75671e-06],
#                ...,
#                [0.90625, 0.855469, -0.198242, ..., 0.0216064, 0.015625,
#                 0.0112915],
#                [0.131836, 0.984375, -0.660156, ..., 0.0216064, 0.015625,
#                 0.0112915],
#                [-0.761719, 0.617188, -0.949219, ..., 0.0216064, 0.015625,
#                 0.0112915]], dtype=bfloat16)
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 16,777,216 (67.1 MB)
#             type=Param,
#             value=Array([[ 0.0100753 ,  0.0358513 , -0.01190613, ..., -0.00789648,
#                     -0.04122052, -0.0072358 ],
#                    [ 0.01194022, -0.0025412 ,  0.0028281 , ...,  0.01092982,
#                      0.03539912, -0.01736014],
#                    [-0.03319066,  0.04874458,  0.01653023, ...,  0.03096069,
#                     -0.02927347, -0.01019738],
#                    ...,
#                    [ 0.02313257,  0.01968604,  0.02166563, ..., -0.04117807,
#                      0.00534283,  0.04277195],
#                    [-0.00045658,  0.00142607, -0.0340396 , ..., -0.03630592,
#                     -0.00250092,  0.00584663],
#                    [ 0.00533373, -0.00284248,  0.00984211, ..., -0.0154912 ,
#                      0.04630296, -0.00863932]], dtype=float32)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 16,777,216 (67.1 MB)
#             type=Param,
#             value=Array([[-0.00647183, -0.00668194, -0.04119152, ...,  0.00699341,
#                     -0.00171038,  0.0012034 ],
#                    [-0.02960737,  0.02951592,  0.03372669, ...,  0.02980521,
#                      0.01888685, -0.01515136],
#                    [ 0.01939499,  0.04795959,  0.01338235, ...,  0.0049495 ,
#                      0.0348004 , -0.03769377],
#                    ...,
#                    [ 0.00755091, -0.01021632,  0.01437405, ..., -0.00637017,
#                      0.04039168,  0.02315849],
#                    [-0.00492391, -0.00428843, -0.00288994, ...,  0.01901618,
#                      0.0048117 ,  0.01031357],
#                    [ 0.00371618, -0.00538945, -0.01895771, ..., -0.03150458,
#                     -0.02655217, -0.01400978]], dtype=float32)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 16,777,216 (67.1 MB)
#             type=Param,
#             value=Array([[ 0.00410375,  0.0208026 , -0.00122085, ..., -0.01508427,
#                     -0.00879241,  0.00380337],
#                    [-0.00121729, -0.00205437, -0.02058795, ...,  0.00660475,
#                     -0.01365874, -0.01459436],
#                    [ 0.0250364 , -0.01342645, -0.00794861, ...,  0.00644656,
#                     -0.00687273,  0.01700261],
#                    ...,
#                    [ 0.00811688, -0.00053215, -0.00340685, ...,  0.01204397,
#                      0.00301375, -0.0094736 ],
#                    [ 0.00713887,  0.00949004, -0.00115369, ..., -0.0185867 ,
#                     -0.0096094 ,  0.00086464],
#                    [-0.00081331, -0.00562202, -0.014799  , ...,  0.01643487,
#                      0.01380456,  0.01003147]], dtype=float32)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 2,048 (8.2 KB)
#           type=Param,
#           value=Array([1., 1., 1., ..., 1., 1., 1.], dtype=float32)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 2,048 (8.2 KB)
#           type=Param,
#           value=Array([1., 1., 1., ..., 1., 1., 1.], dtype=float32)
#         )
#       }
#     },
#     15: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1,048,576 (4.2 MB)
#             type=Param,
#             value=Array([[ 0.00616969,  0.01351005, -0.02026684, ..., -0.01818267,
#                     -0.00285716, -0.01775173],
#                    [-0.02653288,  0.00249199,  0.01921967, ..., -0.00991374,
#                     -0.03800049,  0.01196724],
#                    [ 0.00575888,  0.04021568, -0.02241741, ...,  0.01938724,
#                      0.02628998,  0.01978423],
#                    ...,
#                    [ 0.04063272,  0.00011258,  0.00208533, ..., -0.00110587,
#                     -0.01231117, -0.01321895],
#                    [ 0.00413317, -0.04183673,  0.00299379, ...,  0.04186699,
#                     -0.02038773,  0.00938963],
#                    [ 0.03649232,  0.00439802,  0.00208595, ..., -0.01052136,
#                      0.02993481,  0.00274808]], dtype=float32)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 4,194,304 (16.8 MB)
#             type=Param,
#             value=Array([[ 0.01828942, -0.02512043, -0.00803004, ...,  0.00826035,
#                     -0.03142266, -0.02428006],
#                    [ 0.00688599, -0.0108739 , -0.02515587, ...,  0.00725512,
#                      0.01087263, -0.01384305],
#                    [-0.03429598, -0.02113924,  0.0212516 , ...,  0.04621589,
#                     -0.03452835, -0.00063781],
#                    ...,
#                    [ 0.0009893 ,  0.02081229,  0.00619756, ..., -0.01489383,
#                      0.02065573, -0.03456323],
#                    [ 0.00042196,  0.01112987, -0.03419348, ...,  0.01769945,
#                      0.01441687, -0.00590905],
#                    [ 0.00748851, -0.02854455,  0.03453331, ..., -0.03519133,
#                      0.02477419,  0.00478349]], dtype=float32)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1,048,576 (4.2 MB)
#             type=Param,
#             value=Array([[-0.0484239 , -0.02872801, -0.01094341, ...,  0.01976762,
#                     -0.01590139, -0.00429365],
#                    [ 0.03144925, -0.00816035,  0.00243355, ..., -0.02093528,
#                      0.02386353, -0.01874298],
#                    [ 0.01005583, -0.0085759 , -0.04072347, ..., -0.01973346,
#                      0.02444352,  0.03067728],
#                    ...,
#                    [-0.0094078 , -0.02346815,  0.01222117, ...,  0.00421544,
#                      0.02183605,  0.01462263],
#                    [-0.00385884, -0.00684971,  0.01486214, ...,  0.01327595,
#                     -0.03444532, -0.00658461],
#                    [ 0.01888148,  0.00232501,  0.00577366, ...,  0.00135648,
#                     -0.00167891, -0.02704446]], dtype=float32)
#           )
#         },
#         'cos': Array([[1, 1, 1, ..., 1, 1, 1],
#                [0.539062, 0.75, 0.867188, ..., 1, 1, 1],
#                [-0.416016, 0.123047, 0.5, ..., 1, 1, 1],
#                ...,
#                [-0.425781, 0.515625, -0.980469, ..., 1, 1, 1],
#                [-0.992188, -0.178711, -0.75, ..., 1, 1, 1],
#                [-0.644531, -0.785156, -0.318359, ..., 1, 1, 1]], dtype=bfloat16),
#         'out_proj': {
#           'kernel': VariableState( # 4,194,304 (16.8 MB)
#             type=Param,
#             value=Array([[ 0.02057244, -0.01160328,  0.02507029, ...,  0.03533177,
#                     -0.02050547,  0.0412629 ],
#                    [-0.02847663, -0.00431914,  0.03617016, ..., -0.0203335 ,
#                      0.02733733, -0.0155441 ],
#                    [-0.01021274,  0.01272465,  0.01390354, ..., -0.01528995,
#                     -0.00983557, -0.02361664],
#                    ...,
#                    [ 0.00545192,  0.0305696 , -0.00438334, ..., -0.01927847,
#                     -0.01197631,  0.0029291 ],
#                    [ 0.00695838,  0.02536099,  0.01258609, ..., -0.00708475,
#                      0.00237864, -0.00715088],
#                    [-0.00150958, -0.02234498, -0.0255111 , ..., -0.00128793,
#                     -0.01078657, -0.00186917]], dtype=float32)
#           )
#         },
#         'sin': Array([[0, 0, 0, ..., 0, 0, 0],
#                [0.839844, 0.664062, 0.5, ..., 2.63751e-06, 1.90735e-06,
#                 1.37836e-06],
#                [0.910156, 0.992188, 0.867188, ..., 5.27501e-06, 3.8147e-06,
#                 2.75671e-06],
#                ...,
#                [0.90625, 0.855469, -0.198242, ..., 0.0216064, 0.015625,
#                 0.0112915],
#                [0.131836, 0.984375, -0.660156, ..., 0.0216064, 0.015625,
#                 0.0112915],
#                [-0.761719, 0.617188, -0.949219, ..., 0.0216064, 0.015625,
#                 0.0112915]], dtype=bfloat16)
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 16,777,216 (67.1 MB)
#             type=Param,
#             value=Array([[-0.01486492,  0.01159149,  0.02018676, ..., -0.01092034,
#                      0.00954153,  0.01813558],
#                    [ 0.00695442, -0.00661202,  0.04694543, ..., -0.01660326,
#                      0.00513623, -0.009291  ],
#                    [-0.0313405 , -0.00110865,  0.04863886, ..., -0.00151931,
#                      0.02258844,  0.00802568],
#                    ...,
#                    [ 0.02893807,  0.00182095,  0.01653604, ...,  0.01333997,
#                     -0.01340169, -0.02342975],
#                    [-0.0192347 ,  0.01990399, -0.0159502 , ..., -0.02806926,
#                     -0.04501298,  0.03588046],
#                    [ 0.00919761, -0.01161485,  0.03810061, ...,  0.01717087,
#                      0.0042279 ,  0.00729505]], dtype=float32)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 16,777,216 (67.1 MB)
#             type=Param,
#             value=Array([[-0.01510013,  0.02243953, -0.0257918 , ..., -0.01706941,
#                      0.0064701 ,  0.01789079],
#                    [-0.00552286, -0.01252619, -0.01744934, ...,  0.00644208,
#                      0.01959332,  0.02150593],
#                    [-0.02337675,  0.02220937, -0.03872077, ...,  0.00047479,
#                      0.01367929,  0.02730112],
#                    ...,
#                    [-0.01782827, -0.02990539,  0.02539629, ...,  0.01336844,
#                     -0.00372069,  0.01370366],
#                    [-0.00472704, -0.01168522,  0.03123805, ..., -0.03689308,
#                      0.01915926,  0.00643023],
#                    [ 0.00373928, -0.01343248,  0.01915718, ..., -0.00937934,
#                      0.0059946 , -0.01489524]], dtype=float32)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 16,777,216 (67.1 MB)
#             type=Param,
#             value=Array([[ 0.00493752, -0.01115598,  0.01963977, ...,  0.00097345,
#                     -0.00232161,  0.00658662],
#                    [ 0.00267138, -0.01928159, -0.00909853, ...,  0.00110078,
#                     -0.00481716,  0.01898191],
#                    [ 0.00974372, -0.00114647, -0.01627757, ...,  0.00627455,
#                     -0.01962903, -0.01060987],
#                    ...,
#                    [-0.00278356,  0.00641384,  0.00031103, ...,  0.00707929,
#                     -0.0029684 , -0.0003324 ],
#                    [ 0.00841153, -0.00216161,  0.00076029, ..., -0.01164867,
#                      0.01876062,  0.00679535],
#                    [-0.01426764, -0.00709975, -0.0249791 , ...,  0.00221343,
#                      0.01505709,  0.00494409]], dtype=float32)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 2,048 (8.2 KB)
#           type=Param,
#           value=Array([1., 1., 1., ..., 1., 1., 1.], dtype=float32)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 2,048 (8.2 KB)
#           type=Param,
#           value=Array([1., 1., 1., ..., 1., 1., 1.], dtype=float32)
#         )
#       }
#     }
#   }
# })

# %%
loaded_weights = nnx.state(model)

loaded_weights
# Out:
# State({
#   'final_norm': {
#     'scale': VariableState( # 2,048 (4.1 KB)
#       type=Param,
#       value=Array([2.45312, 2.25, 1.53906, ..., 2.51562, 2.40625, 2.5], dtype=bfloat16)
#     )
#   },
#   'out_head': {
#     'kernel': VariableState( # 262,668,288 (525.3 MB)
#       type=Param,
#       value=Array([[-0.0336914, 0.0167236, -0.013855, ..., 0.0314941, 0.00521851,
#               -0.00765991],
#              [0.00135803, -0.000492096, 0.00958252, ..., 0.00570679,
#               -0.00282288, 0.000492096],
#              [-0.0197754, 0.0402832, -0.0303955, ..., 0.0117188, 0.00196838,
#               -0.0167236],
#              ...,
#              [0.0159912, -0.0427246, 0.00723267, ..., 0.0142212, -0.013855,
#               -0.0314941],
#              [-0.0253906, -0.0197754, -0.0303955, ..., -0.0117188, -0.0197754,
#               0.0117188],
#              [0.0117188, -0.0148315, -0.0349121, ..., 0.0032196, -0.0159912,
#               -0.0214844]], dtype=bfloat16)
#     )
#   },
#   'tok_emb': {
#     'embedding': VariableState( # 262,668,288 (525.3 MB)
#       type=Param,
#       value=Array([[0.00312805, 0.0178223, 0.0209961, ..., -0.00521851, -0.0419922,
#               -0.0334473],
#              [0.0236816, -0.0229492, 0.0198975, ..., -0.00946045, -0.00221252,
#               -0.0395508],
#              [0.0144653, 0.0105591, 0.00982666, ..., 0.00683594, -0.0115967,
#               0.00579834],
#              ...,
#              [-1.05798e-06, 0.0106201, -0.019043, ..., 0.00138855, -0.00177002,
#               0.00970459],
#              [-1.36346e-06, 0.0106201, -0.019043, ..., 0.00138855, -0.00177002,
#               0.00970459],
#              [-1.19209e-06, 0.0106201, -0.019043, ..., 0.00138855, -0.00177002,
#               0.00970459]], dtype=bfloat16)
#     )
#   },
#   'trf_blocks': {
#     0: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1,048,576 (2.1 MB)
#             type=Param,
#             value=Array([[0.0581055, -0.0122681, -0.0771484, ..., -0.0045166, -0.0245361,
#                     0.0187988],
#                    [0.117676, 0.0742188, -0.0385742, ..., 0.00668335, -0.0108643,
#                     0.0239258],
#                    [0.0615234, 0.0576172, -0.00227356, ..., 0.00228882, 0.0419922,
#                     0.0136108],
#                    ...,
#                    [-0.104004, -0.0266113, 0.00306702, ..., 0.00227356, 0.0322266,
#                     0.00331116],
#                    [-0.0311279, -0.0206299, -0.0211182, ..., -0.0272217, 0.0200195,
#                     0.0246582],
#                    [0.0201416, -0.0449219, 0.000984192, ..., -0.00479126, 0.00799561,
#                     0.0266113]], dtype=bfloat16)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 4,194,304 (8.4 MB)
#             type=Param,
#             value=Array([[-0.0179443, 0.012207, 0.0178223, ..., 0.0297852, 0.022583,
#                     -0.0257568],
#                    [0.00662231, 0.0593262, 0.0155029, ..., 0.0351562, -0.0247803,
#                     -0.0537109],
#                    [0.0246582, 0.0551758, 0.0344238, ..., 0.0712891, 0.0351562,
#                     -0.0130615],
#                    ...,
#                    [-0.00872803, -0.0332031, -0.0385742, ..., -0.0717773, -0.0119629,
#                     0.0541992],
#                    [-0.0117188, -0.0153809, -0.0385742, ..., -0.0264893, -0.0286865,
#                     0.00958252],
#                    [0.0201416, 0.0108032, -0.0275879, ..., -0.0286865, -0.0147705,
#                     -0.0027771]], dtype=bfloat16)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1,048,576 (2.1 MB)
#             type=Param,
#             value=Array([[0.0148926, 0.00534058, -0.00130463, ..., -0.00558472,
#                     -0.00704956, -0.0163574],
#                    [0.000854492, -0.00463867, 0.00424194, ..., 0.00109863,
#                     -0.0088501, -0.00376892],
#                    [0.0114746, -0.00866699, -0.00552368, ..., -0.000923157,
#                     -0.00187683, 0.00087738],
#                    ...,
#                    [0.00823975, 0.00205994, 0.00164032, ..., -0.010437, -0.00350952,
#                     -0.00463867],
#                    [-0.00567627, 0.00753784, 0.00280762, ..., -0.0130005,
#                     -0.00215149, -0.00772095],
#                    [-0.00854492, -0.00527954, 0.00576782, ..., 0.00427246, 0.0130615,
#                     -0.00665283]], dtype=bfloat16)
#           )
#         },
#         'cos': Array([[1, 1, 1, ..., 1, 1, 1],
#                [0.539062, 0.789062, 0.90625, ..., 1, 1, 1],
#                [-0.416016, 0.241211, 0.636719, ..., 1, 1, 1],
#                ...,
#                [-0.182617, 0.835938, 0.476562, ..., 1, 1, 1],
#                [-0.925781, 0.996094, 0.0554199, ..., 1, 1, 1],
#                [-0.816406, 0.734375, -0.373047, ..., 1, 1, 1]], dtype=bfloat16),
#         'out_proj': {
#           'kernel': VariableState( # 4,194,304 (8.4 MB)
#             type=Param,
#             value=Array([[0.000109196, 0.00836182, -0.00631714, ..., 0.0110474, 0.00109863,
#                     -0.00376892],
#                    [0.00561523, 0.00762939, -0.0495605, ..., -0.0131836, -0.0246582,
#                     0.0109253],
#                    [0.0142212, -0.00778198, -0.0192871, ..., 0.00306702,
#                     -0.000717163, -0.0119019],
#                    ...,
#                    [-0.00891113, -0.00137329, -0.00921631, ..., 0.00933838,
#                     -0.0078125, 0.00312805],
#                    [-0.00195312, 0.0018692, -0.00402832, ..., 0.00227356,
#                     -0.00915527, 0.000268936],
#                    [0.0118408, -0.00177002, -0.000827789, ..., -0.0090332,
#                     -0.00604248, 0.000984192]], dtype=bfloat16)
#           )
#         },
#         'sin': Array([[0, 0, 0, ..., 0, 0, 0],
#                [0.839844, 0.617188, 0.425781, ..., 2.14204e-07, 1.41561e-07,
#                 9.40636e-08],
#                [0.910156, 0.96875, 0.769531, ..., 4.28408e-07, 2.83122e-07,
#                 1.88127e-07],
#                ...,
#                [0.984375, -0.546875, 0.878906, ..., 0.0280762, 0.0185547,
#                 0.0123291],
#                [0.376953, 0.0844727, 1, ..., 0.0280762, 0.0185547, 0.0123291],
#                [-0.574219, 0.679688, 0.929688, ..., 0.0280762, 0.0185547,
#                 0.0123291]], dtype=bfloat16)
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 16,777,216 (33.6 MB)
#             type=Param,
#             value=Array([[0.026001, -0.00964355, -0.026123, ..., 0.0197754, -0.00259399,
#                     -0.0230713],
#                    [-0.0123291, 0.0224609, -0.00952148, ..., -0.0228271, -0.0109253,
#                     0.00488281],
#                    [-0.0139771, 0.0014801, 0.000249863, ..., -0.019043, 0.00107574,
#                     0.00860596],
#                    ...,
#                    [0.00350952, -0.0272217, -0.0055542, ..., 0.0289307, -0.00369263,
#                     -0.0119629],
#                    [0.0272217, -0.0151367, -0.0119629, ..., -0.0427246, 0.00610352,
#                     -0.00692749],
#                    [0.036377, 0.00236511, -0.0286865, ..., -0.0137329, -0.0140381,
#                     0.00695801]], dtype=bfloat16)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 16,777,216 (33.6 MB)
#             type=Param,
#             value=Array([[-0.0262451, 0.0306396, 0.0432129, ..., 0.0158691, -0.0032196,
#                     -0.00842285],
#                    [0.00262451, -0.00741577, 0.00939941, ..., -0.0380859,
#                     -0.00595093, 0.0145874],
#                    [0.00720215, -0.0180664, 0.0220947, ..., 0.0222168, -0.0141602,
#                     0.015625],
#                    ...,
#                    [-0.0241699, 0.00582886, -0.0039978, ..., -0.00714111, 0.0141602,
#                     0.00367737],
#                    [0.00512695, -0.0378418, 0.0251465, ..., -0.0071106, -0.00860596,
#                     0.00302124],
#                    [-0.0153198, -0.0164795, 0.0185547, ..., 0.0273438, -0.00476074,
#                     -0.00756836]], dtype=bfloat16)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 16,777,216 (33.6 MB)
#             type=Param,
#             value=Array([[-0.0268555, 0.015564, 0.0255127, ..., 0.00148773, -0.000919342,
#                     0.0366211],
#                    [0.0175781, -0.0057373, -0.00823975, ..., -0.0183105, -0.0317383,
#                     -0.0103149],
#                    [-0.000335693, 0.00717163, 0.0317383, ..., -0.0078125,
#                     -0.00717163, 0.00328064],
#                    ...,
#                    [-0.0194092, -0.0233154, 0.0143433, ..., 0.00646973, -0.0332031,
#                     0.00933838],
#                    [0.0115356, 0.000530243, -0.00157166, ..., -0.00262451,
#                     -0.0273438, 0.00665283],
#                    [0.00576782, 0.00212097, 0.00460815, ..., 0.00619507, 0.00436401,
#                     -0.0149536]], dtype=bfloat16)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 2,048 (4.1 KB)
#           type=Param,
#           value=Array([0.154297, 0.182617, 0.255859, ..., 0.216797, 0.208008, 0.149414],      dtype=bfloat16)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 2,048 (4.1 KB)
#           type=Param,
#           value=Array([0.197266, 0.193359, 0.179688, ..., 0.208984, 0.197266, 0.202148],      dtype=bfloat16)
#         )
#       }
#     },
#     1: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1,048,576 (2.1 MB)
#             type=Param,
#             value=Array([[-0.0583496, 0.0311279, -0.0037384, ..., -0.0615234, 0.0668945,
#                     0.0140381],
#                    [0.00473022, 0.0145874, 0.0227051, ..., -0.00631714, 0.00454712,
#                     -0.000257492],
#                    [0.00610352, 0.010376, 0.065918, ..., -0.0393066, -0.032959,
#                     0.0141602],
#                    ...,
#                    [-0.026001, 0.0111694, -0.0240479, ..., 0.000999451, 0.032959,
#                     0.00184631],
#                    [-0.090332, 0.0439453, -0.00692749, ..., -0.0270996, -0.017334,
#                     -0.0366211],
#                    [0.029541, -0.00811768, 0.00915527, ..., 0.00297546, -0.0302734,
#                     -0.00222778]], dtype=bfloat16)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 4,194,304 (8.4 MB)
#             type=Param,
#             value=Array([[-0.0324707, 0.0088501, 0.0253906, ..., -0.0236816, 0.000907898,
#                     0.0251465],
#                    [0.00735474, -0.0016098, -0.00164032, ..., 0.0175781, -0.00952148,
#                     -0.0541992],
#                    [-0.00775146, 0.00270081, -0.0128784, ..., 0.0125732, -0.0119019,
#                     -0.0255127],
#                    ...,
#                    [-0.00198364, 0.00262451, 0.0170898, ..., -0.0264893, -0.0307617,
#                     -0.013855],
#                    [-0.0180664, 0.0380859, -0.00228882, ..., -0.00234985,
#                     -0.00561523, 0.0218506],
#                    [0.00212097, -0.0224609, 0.0332031, ..., 0.0252686, 0.003479,
#                     -0.0258789]], dtype=bfloat16)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1,048,576 (2.1 MB)
#             type=Param,
#             value=Array([[-0.0137939, -0.026123, 0.000816345, ..., 0.0111084, -0.00263977,
#                     -0.0014801],
#                    [-0.00646973, -0.00357056, -0.00476074, ..., -0.000354767,
#                     0.000282288, -0.00848389],
#                    [0.00291443, 0.0236816, 0.00136566, ..., -0.00254822, 0.00494385,
#                     0.0144653],
#                    ...,
#                    [-0.000172615, -0.000782013, 0.00154114, ..., 0.00811768,
#                     0.0168457, 0.00582886],
#                    [-0.00653076, 0.00604248, 0.00344849, ..., -0.00370789,
#                     -0.00340271, -0.0142212],
#                    [-0.0132446, -0.00567627, -0.00257874, ..., 0.0101929, -0.0127563,
#                     -0.0111084]], dtype=bfloat16)
#           )
#         },
#         'cos': Array([[1, 1, 1, ..., 1, 1, 1],
#                [0.539062, 0.789062, 0.90625, ..., 1, 1, 1],
#                [-0.416016, 0.241211, 0.636719, ..., 1, 1, 1],
#                ...,
#                [-0.182617, 0.835938, 0.476562, ..., 1, 1, 1],
#                [-0.925781, 0.996094, 0.0554199, ..., 1, 1, 1],
#                [-0.816406, 0.734375, -0.373047, ..., 1, 1, 1]], dtype=bfloat16),
#         'out_proj': {
#           'kernel': VariableState( # 4,194,304 (8.4 MB)
#             type=Param,
#             value=Array([[-0.0140381, -0.0110474, -0.00143433, ..., -0.00946045, 0.0032959,
#                     -0.00976562],
#                    [-0.020874, -0.0198975, -0.0088501, ..., -0.00466919, 0.0415039,
#                     -0.0131836],
#                    [0.00897217, 0.020874, -0.0149536, ..., -0.00860596, -0.00878906,
#                     0.0209961],
#                    ...,
#                    [-0.024292, -0.0100098, -0.00196838, ..., -0.00643921, 0.00939941,
#                     -0.000362396],
#                    [-0.0218506, 0.0100098, 0.00860596, ..., -0.0211182, -0.0098877,
#                     0.00500488],
#                    [-0.00515747, 0.0351562, -0.0223389, ..., 0.0169678, 0.00872803,
#                     0.00408936]], dtype=bfloat16)
#           )
#         },
#         'sin': Array([[0, 0, 0, ..., 0, 0, 0],
#                [0.839844, 0.617188, 0.425781, ..., 2.14204e-07, 1.41561e-07,
#                 9.40636e-08],
#                [0.910156, 0.96875, 0.769531, ..., 4.28408e-07, 2.83122e-07,
#                 1.88127e-07],
#                ...,
#                [0.984375, -0.546875, 0.878906, ..., 0.0280762, 0.0185547,
#                 0.0123291],
#                [0.376953, 0.0844727, 1, ..., 0.0280762, 0.0185547, 0.0123291],
#                [-0.574219, 0.679688, 0.929688, ..., 0.0280762, 0.0185547,
#                 0.0123291]], dtype=bfloat16)
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 16,777,216 (33.6 MB)
#             type=Param,
#             value=Array([[0.00799561, -0.0187988, -0.00878906, ..., 0.0166016, -0.00927734,
#                     -0.000299454],
#                    [-0.015564, -0.0133667, 0.00613403, ..., -0.0307617, 0.052002,
#                     -0.0180664],
#                    [0.00878906, 0.0139771, -0.000717163, ..., -0.0341797,
#                     -0.000204086, 0.0673828],
#                    ...,
#                    [0.0263672, -0.0327148, 0.029541, ..., 0.00872803, -0.00177002,
#                     0.0839844],
#                    [0.00939941, 0.0297852, 0.00332642, ..., 0.0163574, 0.012146,
#                     0.0419922],
#                    [0.00466919, 0.0400391, -0.0262451, ..., -0.0214844, -0.041748,
#                     -0.0123291]], dtype=bfloat16)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 16,777,216 (33.6 MB)
#             type=Param,
#             value=Array([[-0.0393066, -0.0209961, -0.00326538, ..., 0.0057373, 0.0106812,
#                     0.00402832],
#                    [0.0172119, 0.00163269, -0.010498, ..., -0.0124512, -0.0194092,
#                     -0.000667572],
#                    [0.0142822, -0.00534058, -0.0134277, ..., 0.0105591, 0.0268555,
#                     -0.010498],
#                    ...,
#                    [0.0157471, 0.00842285, 0.0144043, ..., 0.00909424, 0.0117798,
#                     -0.00823975],
#                    [0.0195312, 0.0100708, 0.0163574, ..., 0.0142822, -0.0112305,
#                     0.0050354],
#                    [-0.00164795, -0.0195312, -0.00634766, ..., -0.0192871, 0.0129395,
#                     -0.0240479]], dtype=bfloat16)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 16,777,216 (33.6 MB)
#             type=Param,
#             value=Array([[0.000272751, -0.0200195, 0.0220947, ..., -0.0103149, -0.00241089,
#                     -0.0137939],
#                    [-0.00964355, 0.000155449, 0.0101929, ..., 0.0246582, -0.00209045,
#                     -0.00390625],
#                    [-0.000197411, -0.00552368, -0.00698853, ..., 0.00244141,
#                     -0.0234375, -0.0229492],
#                    ...,
#                    [-0.0380859, 0.000999451, -0.0136719, ..., -0.0170898, 0.0177002,
#                     -0.0100708],
#                    [0.00576782, -0.0218506, 0.0088501, ..., 0.00836182, -0.0128174,
#                     -0.0101929],
#                    [0.0133667, 0.00860596, 0.00312805, ..., -0.0187988, 0.0184326,
#                     -0.0273438]], dtype=bfloat16)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 2,048 (4.1 KB)
#           type=Param,
#           value=Array([0.316406, 0.337891, 0.345703, ..., 0.337891, 0.539062, 0.294922],      dtype=bfloat16)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 2,048 (4.1 KB)
#           type=Param,
#           value=Array([0.265625, 0.261719, 0.19043, ..., 0.267578, 0.216797, 0.269531],      dtype=bfloat16)
#         )
#       }
#     },
#     2: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1,048,576 (2.1 MB)
#             type=Param,
#             value=Array([[0.0571289, -0.0266113, -0.00958252, ..., 0.00872803, 0.0849609,
#                     -0.0361328],
#                    [-0.0114136, 0.006073, -0.0415039, ..., 0.0595703, -0.0163574,
#                     0.0206299],
#                    [0.0444336, -0.0576172, -0.0183105, ..., 0.0444336, -0.116211,
#                     -0.0576172],
#                    ...,
#                    [-0.0371094, 0.0454102, 4.69685e-05, ..., -0.0400391, -0.0483398,
#                     0.0839844],
#                    [0.0393066, -0.0244141, -0.0108643, ..., -0.0791016, -0.027832,
#                     -0.0144043],
#                    [0.0412598, 0.0311279, 0.0412598, ..., 0.0268555, -0.0478516,
#                     -0.0693359]], dtype=bfloat16)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 4,194,304 (8.4 MB)
#             type=Param,
#             value=Array([[0.0258789, -0.020752, 0.0388184, ..., 0.0253906, -0.0490723,
#                     0.0143433],
#                    [0.046875, 0.00558472, 0.00454712, ..., -0.0301514, -0.0163574,
#                     -0.034668],
#                    [-0.00582886, 0.00256348, -0.00378418, ..., 0.00430298,
#                     -0.000328064, 0.00260925],
#                    ...,
#                    [-0.00872803, 0.00469971, 0.0269775, ..., 0.0239258, 0.0510254,
#                     -0.0153809],
#                    [0.0566406, -0.0332031, 0.0137939, ..., 0.000295639, -0.0236816,
#                     -0.0169678],
#                    [-0.0180664, -0.0166016, -0.0118408, ..., -0.00408936, 0.019043,
#                     -0.00872803]], dtype=bfloat16)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1,048,576 (2.1 MB)
#             type=Param,
#             value=Array([[0.00500488, -0.0240479, 0.000305176, ..., 0.00305176,
#                     -0.00527954, 0.00717163],
#                    [0.00112152, 0.00341797, -0.0145874, ..., -0.00379944, -0.0244141,
#                     -2.02656e-05],
#                    [-0.00564575, 0.0065918, 0.00799561, ..., 0.00311279, -0.00209045,
#                     0.0032196],
#                    ...,
#                    [-0.0128174, 0.0166016, 0.0305176, ..., -0.00970459, 0.0018158,
#                     -0.00482178],
#                    [-0.00491333, 0.0055542, 0.00448608, ..., 0.00177765, 0.000268936,
#                     -0.00793457],
#                    [0.010376, -0.0181885, 0.0114136, ..., -0.0067749, -0.0071106,
#                     -0.0341797]], dtype=bfloat16)
#           )
#         },
#         'cos': Array([[1, 1, 1, ..., 1, 1, 1],
#                [0.539062, 0.789062, 0.90625, ..., 1, 1, 1],
#                [-0.416016, 0.241211, 0.636719, ..., 1, 1, 1],
#                ...,
#                [-0.182617, 0.835938, 0.476562, ..., 1, 1, 1],
#                [-0.925781, 0.996094, 0.0554199, ..., 1, 1, 1],
#                [-0.816406, 0.734375, -0.373047, ..., 1, 1, 1]], dtype=bfloat16),
#         'out_proj': {
#           'kernel': VariableState( # 4,194,304 (8.4 MB)
#             type=Param,
#             value=Array([[0.010437, -0.0280762, -0.00479126, ..., 0.00439453, 0.0065918,
#                     -0.017334],
#                    [-0.0132446, 0.00552368, 0.00585938, ..., -0.00219727, 0.00650024,
#                     -0.00160217],
#                    [-0.00549316, 0.000442505, 0.0124512, ..., -0.00939941,
#                     0.00897217, -0.0249023],
#                    ...,
#                    [-0.000854492, 0.000102043, 0.000968933, ..., 0.00127411,
#                     -0.0184326, 0.00131226],
#                    [0.0145874, -0.0135498, -0.0035553, ..., -0.00964355, 0.00558472,
#                     0.0043335],
#                    [-0.00424194, -0.0185547, -0.00479126, ..., -0.000495911,
#                     0.0164795, 0.0126953]], dtype=bfloat16)
#           )
#         },
#         'sin': Array([[0, 0, 0, ..., 0, 0, 0],
#                [0.839844, 0.617188, 0.425781, ..., 2.14204e-07, 1.41561e-07,
#                 9.40636e-08],
#                [0.910156, 0.96875, 0.769531, ..., 4.28408e-07, 2.83122e-07,
#                 1.88127e-07],
#                ...,
#                [0.984375, -0.546875, 0.878906, ..., 0.0280762, 0.0185547,
#                 0.0123291],
#                [0.376953, 0.0844727, 1, ..., 0.0280762, 0.0185547, 0.0123291],
#                [-0.574219, 0.679688, 0.929688, ..., 0.0280762, 0.0185547,
#                 0.0123291]], dtype=bfloat16)
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 16,777,216 (33.6 MB)
#             type=Param,
#             value=Array([[0.0275879, 0.00408936, 0.0137329, ..., 0.00692749, 0.00933838,
#                     -0.0162354],
#                    [0.022583, -0.00174713, 0.000356674, ..., 0.00738525, 0.0267334,
#                     0.00358582],
#                    [-0.006073, -0.00878906, -0.00909424, ..., -0.0172119, -0.0195312,
#                     0.00805664],
#                    ...,
#                    [-0.010498, 0.00579834, 0.00075531, ..., -0.0115356, 0.000267029,
#                     0.0112305],
#                    [0.00137329, 0.0244141, -0.00567627, ..., -0.0100708, -0.00640869,
#                     -0.0115356],
#                    [-0.034668, 0.00878906, -0.0078125, ..., 0.0332031, -0.0126343,
#                     0.0234375]], dtype=bfloat16)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 16,777,216 (33.6 MB)
#             type=Param,
#             value=Array([[-0.019165, 0.0253906, 0.0454102, ..., -0.0297852, -0.0112915,
#                     -0.0209961],
#                    [-0.0113525, -0.0152588, 0.00866699, ..., 0.013916, -0.00213623,
#                     -0.00970459],
#                    [0.0134888, 0.017334, 0.0236816, ..., 0.00473022, -0.00668335,
#                     -0.0120239],
#                    ...,
#                    [-0.0351562, -0.0301514, 0.013855, ..., 0.0200195, -0.00933838,
#                     -0.00430298],
#                    [-0.0168457, 0.00387573, 0.0108032, ..., -0.0244141, 0.00570679,
#                     0.000556946],
#                    [0.00787354, 0.00576782, -0.0178223, ..., 0.0288086, -0.0175781,
#                     -0.00178528]], dtype=bfloat16)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 16,777,216 (33.6 MB)
#             type=Param,
#             value=Array([[-0.00172424, -0.032959, 0.012207, ..., 0.00408936, -0.00302124,
#                     -0.0166016],
#                    [0.00595093, 0.00185394, -0.00408936, ..., -0.0167236,
#                     -0.00994873, -0.00494385],
#                    [0.0383301, 0.0296631, -0.00325012, ..., -0.0120239, -0.0251465,
#                     0.00286865],
#                    ...,
#                    [0.0249023, 0.00169373, 0.00408936, ..., -0.0301514, -0.0205078,
#                     0.00637817],
#                    [-0.0179443, -0.032959, 0.0144653, ..., 0.00994873, -0.0302734,
#                     0.0213623],
#                    [-0.0151367, 0.0262451, -0.0249023, ..., 0.00180054, 0.0200195,
#                     0.0336914]], dtype=bfloat16)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 2,048 (4.1 KB)
#           type=Param,
#           value=Array([0.396484, 0.398438, 0.5, ..., 0.40625, 0.695312, 0.375], dtype=bfloat16)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 2,048 (4.1 KB)
#           type=Param,
#           value=Array([0.306641, 0.304688, 0.225586, ..., 0.3125, 0.271484, 0.3125],      dtype=bfloat16)
#         )
#       }
#     },
#     3: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1,048,576 (2.1 MB)
#             type=Param,
#             value=Array([[0.0581055, 0.0356445, -0.0244141, ..., 0.0297852, -0.0187988,
#                     -0.0351562],
#                    [0.0222168, 0.00137329, -0.0119019, ..., -0.0319824, 0.0654297,
#                     -0.0402832],
#                    [-0.0124512, 0.0224609, 0.0109863, ..., -0.000278473, -0.0600586,
#                     0.0644531],
#                    ...,
#                    [0.0137939, -0.0422363, -0.0336914, ..., 0.0317383, -0.0195312,
#                     0.0126343],
#                    [-0.0109253, -0.0039978, 0.0114136, ..., 0.017334, -0.0688477,
#                     0.00382996],
#                    [-0.0166016, -0.0368652, 0.0123901, ..., 0.00442505, -0.00854492,
#                     -0.00799561]], dtype=bfloat16)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 4,194,304 (8.4 MB)
#             type=Param,
#             value=Array([[-0.00288391, -0.00738525, -0.00238037, ..., -0.0148926,
#                     0.0145264, 0.0483398],
#                    [-0.00334167, -0.00121307, -0.00518799, ..., 0.0412598,
#                     -0.0284424, 0.0227051],
#                    [0.00915527, 0.0197754, 0.00769043, ..., -0.017334, 0.0373535,
#                     -0.00521851],
#                    ...,
#                    [0.00671387, 0.0050354, 0.00337219, ..., -0.0664062, -0.0314941,
#                     0.0253906],
#                    [-0.00872803, -0.00479126, 0.00265503, ..., 0.0107422, 0.0397949,
#                     -0.0198975],
#                    [-0.000436783, 0.0184326, 0.00946045, ..., 0.0224609, -0.00662231,
#                     0.0332031]], dtype=bfloat16)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1,048,576 (2.1 MB)
#             type=Param,
#             value=Array([[-0.0117798, -0.00233459, 0.00897217, ..., -0.00193787,
#                     -0.00518799, -0.00823975],
#                    [0.00312805, 0.0162354, -0.00189972, ..., -0.0185547, 0.00497437,
#                     0.0113525],
#                    [0.0185547, 0.0108643, 0.00341797, ..., -0.00424194, -0.00494385,
#                     0.00732422],
#                    ...,
#                    [0.0147095, -0.0101318, 0.00125122, ..., -0.00323486, -0.00282288,
#                     -0.00114441],
#                    [-0.00228882, 0.00299072, -0.00128937, ..., 0.0038147, 0.00588989,
#                     0.000564575],
#                    [-0.0151367, 0.0090332, 0.0162354, ..., 0.0134888, -0.0166016,
#                     -0.0212402]], dtype=bfloat16)
#           )
#         },
#         'cos': Array([[1, 1, 1, ..., 1, 1, 1],
#                [0.539062, 0.789062, 0.90625, ..., 1, 1, 1],
#                [-0.416016, 0.241211, 0.636719, ..., 1, 1, 1],
#                ...,
#                [-0.182617, 0.835938, 0.476562, ..., 1, 1, 1],
#                [-0.925781, 0.996094, 0.0554199, ..., 1, 1, 1],
#                [-0.816406, 0.734375, -0.373047, ..., 1, 1, 1]], dtype=bfloat16),
#         'out_proj': {
#           'kernel': VariableState( # 4,194,304 (8.4 MB)
#             type=Param,
#             value=Array([[0.00622559, 0.00254822, 0.00360107, ..., 0.012207, -0.0256348,
#                     0.0115967],
#                    [-0.00628662, 0.0302734, -0.00160217, ..., -0.0273438, -0.0249023,
#                     -0.0168457],
#                    [0.0507812, 0.0114746, 0.000644684, ..., -0.0142212, -0.0108643,
#                     -0.0134277],
#                    ...,
#                    [0.00878906, -0.0400391, 0.00216675, ..., -0.00646973, -0.0123901,
#                     -0.0043335],
#                    [0.00212097, 0.0227051, -0.0098877, ..., 0.0385742, -0.00534058,
#                     -0.00305176],
#                    [-0.0155029, 0.0150146, -0.00183868, ..., 0.0212402, -0.0137329,
#                     0.0179443]], dtype=bfloat16)
#           )
#         },
#         'sin': Array([[0, 0, 0, ..., 0, 0, 0],
#                [0.839844, 0.617188, 0.425781, ..., 2.14204e-07, 1.41561e-07,
#                 9.40636e-08],
#                [0.910156, 0.96875, 0.769531, ..., 4.28408e-07, 2.83122e-07,
#                 1.88127e-07],
#                ...,
#                [0.984375, -0.546875, 0.878906, ..., 0.0280762, 0.0185547,
#                 0.0123291],
#                [0.376953, 0.0844727, 1, ..., 0.0280762, 0.0185547, 0.0123291],
#                [-0.574219, 0.679688, 0.929688, ..., 0.0280762, 0.0185547,
#                 0.0123291]], dtype=bfloat16)
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 16,777,216 (33.6 MB)
#             type=Param,
#             value=Array([[-0.0200195, -0.0017395, 0.0322266, ..., -0.0124512, -0.0301514,
#                     -0.0356445],
#                    [-0.0112305, 0.0605469, -0.00167847, ..., -0.041748, -0.00741577,
#                     -0.0107422],
#                    [-0.0253906, 0.0678711, -0.00349426, ..., -0.00335693, 0.013855,
#                     0.020874],
#                    ...,
#                    [0.0149536, 0.0227051, -0.0109253, ..., 0.00482178, 0.0344238,
#                     -0.000511169],
#                    [0.010376, -0.0294189, 0.0158691, ..., 0.0130005, -0.00270081,
#                     0.0272217],
#                    [-0.0196533, -0.0703125, 0.0114746, ..., -0.032959, -0.015625,
#                     -0.0419922]], dtype=bfloat16)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 16,777,216 (33.6 MB)
#             type=Param,
#             value=Array([[-0.0332031, -0.00585938, -0.0203857, ..., 0.0266113, -0.00674438,
#                     0.0288086],
#                    [-0.0195312, 0.0444336, 0.0189209, ..., 0.019165, 0.00891113,
#                     -0.000659943],
#                    [0.0143433, 0.00366211, -0.0019455, ..., -0.0118408, -0.020874,
#                     0.0263672],
#                    ...,
#                    [-0.0256348, 0.00860596, -0.00552368, ..., 0.00970459, 0.0189209,
#                     -0.0158691],
#                    [-0.0163574, -0.0112915, -0.00156403, ..., -0.00177765,
#                     0.00747681, 0.00598145],
#                    [-0.00692749, -0.00613403, -0.0152588, ..., -0.0227051,
#                     -0.0227051, -0.00162506]], dtype=bfloat16)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 16,777,216 (33.6 MB)
#             type=Param,
#             value=Array([[0.0205078, 0.0380859, 0.001091, ..., -0.0145264, 0.00772095,
#                     0.0145874],
#                    [-0.00118256, 0.0307617, 0.000938416, ..., -0.00518799, 0.0166016,
#                     0.00964355],
#                    [0.0128174, -0.0142822, 0.00302124, ..., -0.0137939, 0.00817871,
#                     -0.000827789],
#                    ...,
#                    [0.00460815, -0.0158691, -0.00662231, ..., 0.017334, 0.00689697,
#                     0.000209808],
#                    [-0.020874, -0.00817871, 0.00653076, ..., -0.0476074, 0.00799561,
#                     -0.0195312],
#                    [-0.00946045, 0.00927734, 0.00411987, ..., -0.00561523,
#                     0.00778198, 0.0183105]], dtype=bfloat16)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 2,048 (4.1 KB)
#           type=Param,
#           value=Array([0.396484, 0.439453, 0.355469, ..., 0.371094, 0.597656, 0.363281],      dtype=bfloat16)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 2,048 (4.1 KB)
#           type=Param,
#           value=Array([0.322266, 0.310547, 0.239258, ..., 0.320312, 0.25, 0.324219],      dtype=bfloat16)
#         )
#       }
#     },
#     4: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1,048,576 (2.1 MB)
#             type=Param,
#             value=Array([[0.0170898, -0.0166016, 0.0522461, ..., 0.0517578, 0.102051,
#                     0.0361328],
#                    [-0.0090332, -0.0055542, -0.0201416, ..., -0.0100708, -0.0141602,
#                     -0.0539551],
#                    [-0.00119781, 0.0147705, -0.020752, ..., -0.00352478, 0.0132446,
#                     0.115234],
#                    ...,
#                    [0.0532227, 0.00056076, -0.0299072, ..., -0.00793457, -0.048584,
#                     0.00112915],
#                    [0.00689697, 0.00765991, -0.00189972, ..., -0.000335693,
#                     0.0947266, -0.0517578],
#                    [0.0517578, -0.02771, 0.0163574, ..., 0.0224609, 0.0279541,
#                     -0.00610352]], dtype=bfloat16)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 4,194,304 (8.4 MB)
#             type=Param,
#             value=Array([[-0.00150299, 0.0136719, -0.00799561, ..., -0.0216064, 0.0186768,
#                     -0.0201416],
#                    [0.0183105, 0.00570679, 0.0098877, ..., -0.0257568, -0.0198975,
#                     -0.00567627],
#                    [0.019043, -0.00376892, -0.00328064, ..., -0.00698853, 0.0192871,
#                     -0.00543213],
#                    ...,
#                    [-0.00927734, -0.0162354, -0.022583, ..., -0.0559082, 0.0522461,
#                     0.0187988],
#                    [0.00515747, 0.0111084, 0.0137329, ..., -0.0228271, 0.00811768,
#                     0.00162506],
#                    [-0.0405273, -0.0116577, -0.0233154, ..., -0.0219727, 0.0240479,
#                     -0.0213623]], dtype=bfloat16)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1,048,576 (2.1 MB)
#             type=Param,
#             value=Array([[0.00561523, -0.000991821, 0.0109863, ..., 0.00695801,
#                     0.000808716, 0.027832],
#                    [-0.0366211, -0.00976562, 0.00515747, ..., -0.015625, 0.00897217,
#                     -0.010376],
#                    [-0.00167084, 0.0148315, 0.000356674, ..., 0.0088501, -0.00598145,
#                     0.00358582],
#                    ...,
#                    [0.0170898, -0.00457764, -0.0118408, ..., 0.00579834, -0.00558472,
#                     0.00479126],
#                    [0.00146484, -0.00448608, 0.00531006, ..., 0.00805664, 0.00268555,
#                     0.00662231],
#                    [0.000785828, 0.00787354, -0.0239258, ..., -0.00952148, 0.0268555,
#                     -0.00891113]], dtype=bfloat16)
#           )
#         },
#         'cos': Array([[1, 1, 1, ..., 1, 1, 1],
#                [0.539062, 0.789062, 0.90625, ..., 1, 1, 1],
#                [-0.416016, 0.241211, 0.636719, ..., 1, 1, 1],
#                ...,
#                [-0.182617, 0.835938, 0.476562, ..., 1, 1, 1],
#                [-0.925781, 0.996094, 0.0554199, ..., 1, 1, 1],
#                [-0.816406, 0.734375, -0.373047, ..., 1, 1, 1]], dtype=bfloat16),
#         'out_proj': {
#           'kernel': VariableState( # 4,194,304 (8.4 MB)
#             type=Param,
#             value=Array([[0.00248718, 0.0269775, 0.00119781, ..., 0.0111694, -0.0310059,
#                     -0.00756836],
#                    [-0.00150299, -0.012207, -0.00248718, ..., -0.0164795, 0.0317383,
#                     0.00263977],
#                    [-0.00830078, 0.00183105, -0.0071106, ..., 0.00616455, 0.0228271,
#                     -0.000858307],
#                    ...,
#                    [0.0143433, -0.000732422, 0.00157928, ..., 0.00119781, 0.00491333,
#                     -0.0131226],
#                    [0.0419922, -0.00106812, -0.00123596, ..., 0.019165, -0.0142822,
#                     0.0219727],
#                    [0.0103149, -0.0067749, 0.0067749, ..., 0.0209961, 0.00909424,
#                     -0.00259399]], dtype=bfloat16)
#           )
#         },
#         'sin': Array([[0, 0, 0, ..., 0, 0, 0],
#                [0.839844, 0.617188, 0.425781, ..., 2.14204e-07, 1.41561e-07,
#                 9.40636e-08],
#                [0.910156, 0.96875, 0.769531, ..., 4.28408e-07, 2.83122e-07,
#                 1.88127e-07],
#                ...,
#                [0.984375, -0.546875, 0.878906, ..., 0.0280762, 0.0185547,
#                 0.0123291],
#                [0.376953, 0.0844727, 1, ..., 0.0280762, 0.0185547, 0.0123291],
#                [-0.574219, 0.679688, 0.929688, ..., 0.0280762, 0.0185547,
#                 0.0123291]], dtype=bfloat16)
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 16,777,216 (33.6 MB)
#             type=Param,
#             value=Array([[0.00415039, -0.0108643, -0.0169678, ..., -0.0209961, -0.0192871,
#                     -0.0111694],
#                    [0.0505371, -0.0284424, 0.0169678, ..., -0.00982666, 0.00184631,
#                     0.0122681],
#                    [-0.0103149, -0.0200195, 0.00062561, ..., -0.00305176, -0.041748,
#                     -0.0192871],
#                    ...,
#                    [0.0673828, 0.0358887, -0.03125, ..., 0.0163574, 0.00653076,
#                     0.0216064],
#                    [0.020752, -0.0111084, -0.0153198, ..., -0.00161743, 0.0358887,
#                     -0.0234375],
#                    [-0.0213623, -0.0454102, -0.0247803, ..., 0.019043, -0.00976562,
#                     -0.00656128]], dtype=bfloat16)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 16,777,216 (33.6 MB)
#             type=Param,
#             value=Array([[-0.000375748, 0.0125732, 0.00309753, ..., -0.0132446, 0.00860596,
#                     -0.03125],
#                    [-0.00274658, 0.0114746, 0.0101929, ..., 0.00396729, -0.0037384,
#                     0.0019989],
#                    [0.000398636, 0.00619507, 0.00775146, ..., 0.0148926, 0.00582886,
#                     0.00488281],
#                    ...,
#                    [0.00933838, 0.00588989, 0.00424194, ..., -0.0109253, -0.003479,
#                     -0.0124512],
#                    [0.00386047, -0.0230713, -0.0158691, ..., -0.00717163,
#                     -0.00643921, 0.00701904],
#                    [-0.0126343, 0.0380859, -0.00512695, ..., 0.0117188, -0.00427246,
#                     0.00335693]], dtype=bfloat16)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 16,777,216 (33.6 MB)
#             type=Param,
#             value=Array([[-0.00117493, -0.000434875, -0.0142822, ..., 0.0158691, 0.0234375,
#                     -0.00543213],
#                    [0.0131836, -0.0115356, -0.00163269, ..., 0.00799561, 0.0163574,
#                     -0.0222168],
#                    [0.0119019, 0.0368652, 0.000843048, ..., 0.00253296, -0.0233154,
#                     -0.0027771],
#                    ...,
#                    [-0.010498, 0.0219727, -0.010437, ..., 0.00665283, 0.0130615,
#                     0.0125122],
#                    [0.00933838, -0.0154419, -0.00363159, ..., -0.0263672, 0.00671387,
#                     0.00112152],
#                    [-0.00265503, -0.0115967, 0.00698853, ..., -0.00823975, -0.010376,
#                     0.000919342]], dtype=bfloat16)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 2,048 (4.1 KB)
#           type=Param,
#           value=Array([0.404297, 0.416016, 0.351562, ..., 0.410156, 0.585938, 0.375],      dtype=bfloat16)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 2,048 (4.1 KB)
#           type=Param,
#           value=Array([0.330078, 0.333984, 0.209961, ..., 0.330078, 0.253906, 0.333984],      dtype=bfloat16)
#         )
#       }
#     },
#     5: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1,048,576 (2.1 MB)
#             type=Param,
#             value=Array([[0.00927734, 0.0147095, 0.0127563, ..., -0.0664062, 0.0157471,
#                     -0.0568848],
#                    [0.00289917, 0.00872803, -0.0214844, ..., -0.00457764, -0.045166,
#                     -0.0800781],
#                    [0.0280762, -0.0216064, -0.0532227, ..., 0.0273438, -0.00976562,
#                     0.0150146],
#                    ...,
#                    [0.0214844, -0.0272217, 0.0410156, ..., -0.0617676, 0.0395508,
#                     -0.0177002],
#                    [0.00564575, 0.00151062, -0.0322266, ..., 0.0358887, 0.0385742,
#                     -0.0100708],
#                    [0.00909424, -0.0169678, -0.00314331, ..., -0.0488281, 0.0177002,
#                     0.0673828]], dtype=bfloat16)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 4,194,304 (8.4 MB)
#             type=Param,
#             value=Array([[-0.00592041, -0.00188446, -0.00518799, ..., 0.00408936,
#                     -0.0283203, -0.00915527],
#                    [0.0120239, -0.00793457, 0.00357056, ..., -0.0186768, 0.0200195,
#                     0.0449219],
#                    [0.000480652, -0.00500488, -0.00674438, ..., -0.019165,
#                     -0.00173187, 0.0256348],
#                    ...,
#                    [-0.0124512, 0.0140991, 0.00162506, ..., 0.0245361, 0.000576019,
#                     -0.0127563],
#                    [0.00454712, -0.00030899, 0.0131836, ..., 0.0212402, -0.0148926,
#                     0.017334],
#                    [0.0137329, -0.0211182, -0.0170898, ..., -0.000391006, 0.0111084,
#                     0.0197754]], dtype=bfloat16)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1,048,576 (2.1 MB)
#             type=Param,
#             value=Array([[0.017334, -0.0159912, 0.0139771, ..., -0.0055542, 0.00689697,
#                     0.00872803],
#                    [-0.0166016, -0.00650024, -0.000492096, ..., 0.013855, 0.00805664,
#                     -0.0332031],
#                    [-0.00209045, 0.0017395, 0.003479, ..., -0.00546265, 0.0067749,
#                     -0.00186157],
#                    ...,
#                    [0.0300293, -0.00305176, -0.0123291, ..., 0.00582886, -0.00753784,
#                     -0.00364685],
#                    [-0.0177002, 0.00976562, 0.00500488, ..., 0.00915527, 0.00891113,
#                     0.00527954],
#                    [0.00115204, -0.0219727, -0.00128174, ..., 0.0172119, -0.0106201,
#                     0.0161133]], dtype=bfloat16)
#           )
#         },
#         'cos': Array([[1, 1, 1, ..., 1, 1, 1],
#                [0.539062, 0.789062, 0.90625, ..., 1, 1, 1],
#                [-0.416016, 0.241211, 0.636719, ..., 1, 1, 1],
#                ...,
#                [-0.182617, 0.835938, 0.476562, ..., 1, 1, 1],
#                [-0.925781, 0.996094, 0.0554199, ..., 1, 1, 1],
#                [-0.816406, 0.734375, -0.373047, ..., 1, 1, 1]], dtype=bfloat16),
#         'out_proj': {
#           'kernel': VariableState( # 4,194,304 (8.4 MB)
#             type=Param,
#             value=Array([[0.0432129, 0.00144196, -0.00323486, ..., -0.0200195, -0.00964355,
#                     -0.00775146],
#                    [-0.0130005, 0.0030365, -0.00579834, ..., 0.00250244, -0.0268555,
#                     0.000155449],
#                    [-0.00393677, 0.000216484, 0.00149536, ..., 0.0186768, -0.0143433,
#                     -0.0197754],
#                    ...,
#                    [0.03125, 0.0219727, 0.00570679, ..., 0.0126343, 0.00558472,
#                     0.0018692],
#                    [0.00799561, -0.00708008, 0.00253296, ..., -0.00262451, 0.0285645,
#                     -0.00909424],
#                    [0.0205078, 0.0140991, -0.00726318, ..., 0.0100098, 0.00726318,
#                     0.0158691]], dtype=bfloat16)
#           )
#         },
#         'sin': Array([[0, 0, 0, ..., 0, 0, 0],
#                [0.839844, 0.617188, 0.425781, ..., 2.14204e-07, 1.41561e-07,
#                 9.40636e-08],
#                [0.910156, 0.96875, 0.769531, ..., 4.28408e-07, 2.83122e-07,
#                 1.88127e-07],
#                ...,
#                [0.984375, -0.546875, 0.878906, ..., 0.0280762, 0.0185547,
#                 0.0123291],
#                [0.376953, 0.0844727, 1, ..., 0.0280762, 0.0185547, 0.0123291],
#                [-0.574219, 0.679688, 0.929688, ..., 0.0280762, 0.0185547,
#                 0.0123291]], dtype=bfloat16)
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 16,777,216 (33.6 MB)
#             type=Param,
#             value=Array([[-0.017334, -0.03125, 0.0161133, ..., -0.027832, 0.0251465,
#                     0.017334],
#                    [0.026123, -0.0202637, 0.0111694, ..., 0.0172119, 0.0615234,
#                     0.0152588],
#                    [-0.0168457, 0.0201416, 0.0108643, ..., 0.00259399, 0.0478516,
#                     0.00634766],
#                    ...,
#                    [-0.0159912, -0.019043, -0.0341797, ..., 0.0181885, 0.0559082,
#                     -0.0306396],
#                    [-0.000850677, -0.0241699, -0.00872803, ..., 0.0133667, 0.034668,
#                     0.0361328],
#                    [0.00860596, -0.0432129, 0.0115356, ..., -0.0255127, -0.0230713,
#                     -0.00540161]], dtype=bfloat16)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 16,777,216 (33.6 MB)
#             type=Param,
#             value=Array([[0.0174561, 0.0297852, -0.0439453, ..., -0.0043335, 0.00680542,
#                     -0.019043],
#                    [0.00202942, 0.00149536, 0.0253906, ..., 0.0407715, 0.00411987,
#                     -0.0103149],
#                    [0.0088501, 0.00756836, -0.00148773, ..., -0.000154495,
#                     -0.00094986, 0.0255127],
#                    ...,
#                    [0.00463867, 0.0090332, 0.0473633, ..., 0.00769043, -0.024292,
#                     0.00286865],
#                    [-0.0102539, 0.001297, -0.0400391, ..., 0.00292969, 0.00332642,
#                     -0.000858307],
#                    [0.0279541, -0.00952148, -0.0410156, ..., 0.00842285, 0.00576782,
#                     0.027832]], dtype=bfloat16)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 16,777,216 (33.6 MB)
#             type=Param,
#             value=Array([[0.0230713, 0.0101318, -0.00463867, ..., -0.0341797, -0.00811768,
#                     -0.0151978],
#                    [0.0351562, -0.0112305, 0.00531006, ..., 0.000436783, 0.00546265,
#                     0.0105591],
#                    [-0.0150146, 0.00222778, -0.001297, ..., 0.0250244, -0.00927734,
#                     -0.0236816],
#                    ...,
#                    [0.00656128, 0.0196533, -0.00695801, ..., 0.0152588, -0.00224304,
#                     0.022583],
#                    [-0.0157471, -0.0057373, 0.010376, ..., 0.00915527, -0.00772095,
#                     0.0145264],
#                    [-0.0268555, -0.0144043, 0.0114136, ..., 0.0198975, 0.0148926,
#                     -0.00891113]], dtype=bfloat16)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 2,048 (4.1 KB)
#           type=Param,
#           value=Array([0.472656, 0.507812, 0.347656, ..., 0.400391, 0.554688, 0.414062],      dtype=bfloat16)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 2,048 (4.1 KB)
#           type=Param,
#           value=Array([0.34375, 0.345703, 0.197266, ..., 0.353516, 0.267578, 0.349609],      dtype=bfloat16)
#         )
#       }
#     },
#     6: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1,048,576 (2.1 MB)
#             type=Param,
#             value=Array([[-0.0197754, -0.0368652, 0.0157471, ..., 0.0255127, -0.0605469,
#                     -0.00509644],
#                    [0.0227051, 0.0067749, 0.0146484, ..., 0.0986328, -0.0222168,
#                     -0.0405273],
#                    [0.0168457, -0.0253906, 0.0383301, ..., -0.0708008, -0.0187988,
#                     -0.0952148],
#                    ...,
#                    [-0.0116577, 0.0114136, -0.00260925, ..., 0.0495605, -0.0219727,
#                     0.0493164],
#                    [0.00488281, -0.0258789, 0.00772095, ..., -0.0257568, 0.0249023,
#                     -0.0527344],
# ...
#                    ...,
#                    [0.00964355, -0.0246582, -0.0133667, ..., -0.00704956, -0.0175781,
#                     0.012146],
#                    [-0.00386047, 0.00741577, -0.0136108, ..., 0.0098877, -0.0241699,
#                     -0.00149536],
#                    [-0.00799561, -0.0201416, -0.0131836, ..., 0.0128174, -0.00823975,
#                     0.0473633]], dtype=bfloat16)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 2,048 (4.1 KB)
#           type=Param,
#           value=Array([0.59375, 0.482422, 0.550781, ..., 0.503906, 0.482422, 0.466797],      dtype=bfloat16)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 2,048 (4.1 KB)
#           type=Param,
#           value=Array([0.490234, 0.486328, 0.359375, ..., 0.480469, 0.480469, 0.488281],      dtype=bfloat16)
#         )
#       }
#     },
#     14: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1,048,576 (2.1 MB)
#             type=Param,
#             value=Array([[0.00138092, -0.010376, 0.0180664, ..., -0.0314941, -0.00787354,
#                     -0.000402451],
#                    [0.0195312, 0.0219727, -0.0319824, ..., -0.0214844, -0.0174561,
#                     0.0045166],
#                    [0.0123901, 0.0449219, -0.0539551, ..., 0.00193024, -0.0311279,
#                     0.0148926],
#                    ...,
#                    [0.00698853, 0.00576782, -0.0286865, ..., 0.0235596, -0.00674438,
#                     -0.00939941],
#                    [-0.0246582, -0.00650024, -0.0114746, ..., 0.000671387,
#                     0.00588989, 0.00982666],
#                    [0.00111389, 0.00604248, 0.0108032, ..., -0.0213623, 0.00695801,
#                     -0.0102539]], dtype=bfloat16)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 4,194,304 (8.4 MB)
#             type=Param,
#             value=Array([[-0.000171661, -0.00656128, 0.00216675, ..., 0.0195312, 0.0219727,
#                     0.012146],
#                    [0.0224609, 0.00811768, 0.00701904, ..., -0.00897217, 0.0131836,
#                     0.013916],
#                    [0.00817871, 0.0317383, 0.0212402, ..., 0.0123291, -0.006073,
#                     -0.0285645],
#                    ...,
#                    [0.0339355, -0.00994873, 0.0251465, ..., -0.00337219, 0.0327148,
#                     0.0125732],
#                    [0.0137329, -0.0187988, 0.020874, ..., -0.000770569, -0.0388184,
#                     0.00772095],
#                    [0.00759888, -0.0130005, 0.00970459, ..., -0.00151062, 0.0144043,
#                     -0.0390625]], dtype=bfloat16)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1,048,576 (2.1 MB)
#             type=Param,
#             value=Array([[-0.0129395, 0.0297852, 0.0266113, ..., -0.00817871, -0.0219727,
#                     -0.00154114],
#                    [-0.0693359, 0.0202637, -0.0307617, ..., 0.00579834, 0.00312805,
#                     0.0019455],
#                    [-0.000556946, -0.0184326, 0.0314941, ..., 0.09375, -0.136719,
#                     0.103516],
#                    ...,
#                    [0.0244141, -0.00604248, 0.0126953, ..., 0.0140991, -0.029541,
#                     -0.0235596],
#                    [0.0100098, 0.0257568, -0.0159912, ..., 0.0148926, -0.0307617,
#                     -0.0231934],
#                    [-0.0197754, -0.0174561, -0.0415039, ..., 0.0108643, -0.0163574,
#                     0.0202637]], dtype=bfloat16)
#           )
#         },
#         'cos': Array([[1, 1, 1, ..., 1, 1, 1],
#                [0.539062, 0.789062, 0.90625, ..., 1, 1, 1],
#                [-0.416016, 0.241211, 0.636719, ..., 1, 1, 1],
#                ...,
#                [-0.182617, 0.835938, 0.476562, ..., 1, 1, 1],
#                [-0.925781, 0.996094, 0.0554199, ..., 1, 1, 1],
#                [-0.816406, 0.734375, -0.373047, ..., 1, 1, 1]], dtype=bfloat16),
#         'out_proj': {
#           'kernel': VariableState( # 4,194,304 (8.4 MB)
#             type=Param,
#             value=Array([[0.0159912, 0.0100708, -0.00387573, ..., -0.0336914, 0.010498,
#                     0.00741577],
#                    [-0.0116577, 0.00668335, 0.00164795, ..., 0.0032959, -0.0419922,
#                     -0.0209961],
#                    [0.0118408, 0.0158691, 0.0137329, ..., -0.00787354, -0.0055542,
#                     -0.0140381],
#                    ...,
#                    [3.38554e-05, 0.017334, 0.0209961, ..., 0.0495605, 0.0263672,
#                     -0.00442505],
#                    [0.000911713, 0.00946045, 0.0158691, ..., 0.0498047, -0.0317383,
#                     -0.0109863],
#                    [-0.0078125, -0.0195312, -0.00717163, ..., -0.0181885, 0.00613403,
#                     -0.0197754]], dtype=bfloat16)
#           )
#         },
#         'sin': Array([[0, 0, 0, ..., 0, 0, 0],
#                [0.839844, 0.617188, 0.425781, ..., 2.14204e-07, 1.41561e-07,
#                 9.40636e-08],
#                [0.910156, 0.96875, 0.769531, ..., 4.28408e-07, 2.83122e-07,
#                 1.88127e-07],
#                ...,
#                [0.984375, -0.546875, 0.878906, ..., 0.0280762, 0.0185547,
#                 0.0123291],
#                [0.376953, 0.0844727, 1, ..., 0.0280762, 0.0185547, 0.0123291],
#                [-0.574219, 0.679688, 0.929688, ..., 0.0280762, 0.0185547,
#                 0.0123291]], dtype=bfloat16)
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 16,777,216 (33.6 MB)
#             type=Param,
#             value=Array([[0.0415039, 0.0050354, 0.0102539, ..., 0.0050354, 0.000793457,
#                     0.00534058],
#                    [-0.0109253, -0.0109253, -0.00524902, ..., -0.020752, -0.00439453,
#                     -0.00909424],
#                    [-0.000282288, -0.00897217, 0.0192871, ..., -0.0111694, -0.019043,
#                     -0.0262451],
#                    ...,
#                    [0.0150757, -0.0147705, -0.0280762, ..., -0.0341797, -0.0100708,
#                     -0.0155029],
#                    [0.0111084, 0.00946045, -0.00344849, ..., -0.0175781, -0.00799561,
#                     -0.0140381],
#                    [0.00350952, -0.0170898, 0.00331116, ..., -0.0375977, -0.0112305,
#                     -0.0140381]], dtype=bfloat16)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 16,777,216 (33.6 MB)
#             type=Param,
#             value=Array([[0.0412598, -0.0332031, -0.00448608, ..., 0.00656128, 0.00288391,
#                     0.00817871],
#                    [-0.0127563, -0.003479, -0.0155029, ..., -0.0217285, -0.00102997,
#                     0.00964355],
#                    [0.0185547, 0.00378418, 0.0065918, ..., 0.000991821, 0.00144196,
#                     0.0400391],
#                    ...,
#                    [0.00717163, -0.0375977, -0.0120239, ..., -0.0158691, 0.026001,
#                     -0.0170898],
#                    [0.0216064, -0.00300598, 0.00454712, ..., -0.0249023, 0.00708008,
#                     -0.0107422],
#                    [0.0139771, -0.00933838, -0.0145264, ..., -0.0147095, 0.0186768,
#                     -0.0108032]], dtype=bfloat16)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 16,777,216 (33.6 MB)
#             type=Param,
#             value=Array([[-0.0429688, 0.0161133, 0.0311279, ..., 0.00598145, 0.0432129,
#                     0.0202637],
#                    [0.00946045, 0.00927734, 0.0030365, ..., -0.0310059, 0.0175781,
#                     0.0139771],
#                    [-0.000999451, 0.0142212, 0.00750732, ..., 0.0117188, -0.00958252,
#                     0.00799561],
#                    ...,
#                    [0.0106812, 0.00534058, 0.00909424, ..., 0.0043335, 0.0185547,
#                     0.0301514],
#                    [0.0195312, -0.0106812, 0.0231934, ..., 0.0119019, 0.0139771,
#                     0.0356445],
#                    [0.0101318, -0.0123291, -0.0100708, ..., 0.0246582, 0.0351562,
#                     -0.00524902]], dtype=bfloat16)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 2,048 (4.1 KB)
#           type=Param,
#           value=Array([0.429688, 0.398438, 0.605469, ..., 0.419922, 0.503906, 0.394531],      dtype=bfloat16)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 2,048 (4.1 KB)
#           type=Param,
#           value=Array([0.503906, 0.507812, 0.410156, ..., 0.496094, 0.498047, 0.519531],      dtype=bfloat16)
#         )
#       }
#     },
#     15: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1,048,576 (2.1 MB)
#             type=Param,
#             value=Array([[-0.0236816, -0.0305176, -0.00102997, ..., 0.00622559, 0.00106049,
#                     0.0132446],
#                    [-0.0356445, 0.0131836, -0.0483398, ..., -0.0141602, 0.0027771,
#                     0.0203857],
#                    [-0.0319824, 0.0202637, -0.00512695, ..., 0.0134277, 0.0229492,
#                     0.0286865],
#                    ...,
#                    [0.029541, 0.0039978, 0.0223389, ..., 0.00247192, 0.00424194,
#                     0.00646973],
#                    [-0.0166016, 0.000511169, -0.00267029, ..., -0.0146484,
#                     -0.00332642, -0.0112915],
#                    [0.0820312, -0.0397949, 0.0218506, ..., 0.00165558, -0.00177765,
#                     0.00346375]], dtype=bfloat16)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 4,194,304 (8.4 MB)
#             type=Param,
#             value=Array([[-0.00509644, 0.00358582, 0.0016098, ..., 0.00741577, 0.0150757,
#                     0.0527344],
#                    [-0.0527344, 0.00102997, 0.0032196, ..., 0.0284424, 0.024292,
#                     -0.0174561],
#                    [0.0123291, -0.0227051, -0.0195312, ..., 0.0289307, -0.00964355,
#                     -0.00805664],
#                    ...,
#                    [-0.0167236, 0.0090332, -0.010376, ..., 0.00387573, -0.00190735,
#                     -0.0600586],
#                    [-0.00610352, -0.00430298, 0.00915527, ..., 0.0169678, 0.00302124,
#                     -0.0844727],
#                    [0.015564, 0.00598145, 0.00460815, ..., 0.0478516, -0.0281982,
#                     0.02771]], dtype=bfloat16)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1,048,576 (2.1 MB)
#             type=Param,
#             value=Array([[0.0283203, 0.0111694, -0.0488281, ..., 0.00860596, 0.0249023,
#                     0.0227051],
#                    [-0.00921631, -0.0177002, -0.00390625, ..., -0.0283203,
#                     -0.00292969, 0.0183105],
#                    [-0.00267029, -0.00482178, 0.00396729, ..., 0.0163574, -0.0351562,
#                     0.0168457],
#                    ...,
#                    [0.0354004, -0.00291443, -0.0142822, ..., -0.015625, 0.034668,
#                     -0.00933838],
#                    [-0.0327148, 0.00157166, 0.043457, ..., -0.0102539, 0.0140991,
#                     -0.0120239],
#                    [-0.0466309, -0.00308228, -0.0145264, ..., 0.0137329, -0.0224609,
#                     -0.00698853]], dtype=bfloat16)
#           )
#         },
#         'cos': Array([[1, 1, 1, ..., 1, 1, 1],
#                [0.539062, 0.789062, 0.90625, ..., 1, 1, 1],
#                [-0.416016, 0.241211, 0.636719, ..., 1, 1, 1],
#                ...,
#                [-0.182617, 0.835938, 0.476562, ..., 1, 1, 1],
#                [-0.925781, 0.996094, 0.0554199, ..., 1, 1, 1],
#                [-0.816406, 0.734375, -0.373047, ..., 1, 1, 1]], dtype=bfloat16),
#         'out_proj': {
#           'kernel': VariableState( # 4,194,304 (8.4 MB)
#             type=Param,
#             value=Array([[0.0134888, 0.0194092, -0.00610352, ..., 0.0143433, 0.0146484,
#                     -0.00616455],
#                    [-0.0101318, 0.00263977, 0.0174561, ..., -0.0119629, 0.0206299,
#                     -0.0230713],
#                    [-0.0161133, -0.000854492, -0.0213623, ..., 0.00662231, 0.0284424,
#                     -0.00128174],
#                    ...,
#                    [-0.0114746, 0.0219727, 0.0297852, ..., 0.0154419, -0.0286865,
#                     0.0020752],
#                    [0.0297852, 0.0266113, -0.081543, ..., 0.00793457, -0.0010376,
#                     0.0145874],
#                    [0.00325012, 0.0256348, -0.0576172, ..., -0.00317383, 0.00958252,
#                     -0.0205078]], dtype=bfloat16)
#           )
#         },
#         'sin': Array([[0, 0, 0, ..., 0, 0, 0],
#                [0.839844, 0.617188, 0.425781, ..., 2.14204e-07, 1.41561e-07,
#                 9.40636e-08],
#                [0.910156, 0.96875, 0.769531, ..., 4.28408e-07, 2.83122e-07,
#                 1.88127e-07],
#                ...,
#                [0.984375, -0.546875, 0.878906, ..., 0.0280762, 0.0185547,
#                 0.0123291],
#                [0.376953, 0.0844727, 1, ..., 0.0280762, 0.0185547, 0.0123291],
#                [-0.574219, 0.679688, 0.929688, ..., 0.0280762, 0.0185547,
#                 0.0123291]], dtype=bfloat16)
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 16,777,216 (33.6 MB)
#             type=Param,
#             value=Array([[0.00830078, 0.0178223, 0.00341797, ..., 0.0127563, 0.0230713,
#                     -0.00921631],
#                    [0.0311279, -0.0123901, -0.0119629, ..., 0.0101318, 0.00230408,
#                     -0.012085],
#                    [-0.0153198, -0.00540161, 0.0131226, ..., -0.00854492, 0.0349121,
#                     0.0299072],
#                    ...,
#                    [-0.015564, -0.00704956, 0.026001, ..., -0.0170898, -0.00201416,
#                     0.0102539],
#                    [-0.0119629, -0.00300598, 0.0158691, ..., -0.0168457, 0.0035553,
#                     -0.0115356],
#                    [0.0211182, -0.0186768, 0.00270081, ..., 0.00491333, -0.00216675,
#                     -0.0185547]], dtype=bfloat16)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 16,777,216 (33.6 MB)
#             type=Param,
#             value=Array([[-0.00723267, -0.00227356, 0.00111389, ..., -0.00393677,
#                     0.0130005, -0.0537109],
#                    [-0.0128784, -0.0279541, -0.000144958, ..., -0.0216064, 0.0106201,
#                     0.0288086],
#                    [-0.0185547, 0.0197754, 0.0158691, ..., 0.00537109, 0.0178223,
#                     0.00628662],
#                    ...,
#                    [-0.0302734, 0.0224609, -0.0400391, ..., 0.00110626, -0.00111389,
#                     -0.00135803],
#                    [0.0135498, -0.0158691, -0.0170898, ..., -0.00442505, -0.0227051,
#                     -0.0264893],
#                    [0.000823975, -0.00704956, 0.00915527, ..., 0.0336914, 0.00205994,
#                     0.00396729]], dtype=bfloat16)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 16,777,216 (33.6 MB)
#             type=Param,
#             value=Array([[0.0286865, -0.0288086, -0.00171661, ..., 0.0183105, -0.00320435,
#                     0.0185547],
#                    [-0.00244141, 0.0078125, -0.0119629, ..., 0.000518799,
#                     0.000553131, 0.0155029],
#                    [-0.00445557, 0.0108643, -0.0239258, ..., 0.0234375, -0.0169678,
#                     0.00759888],
#                    ...,
#                    [-0.0267334, -0.00823975, -0.00823975, ..., -0.010498,
#                     -0.00817871, -0.015625],
#                    [0.0253906, -0.00222778, 0.00170898, ..., 0.00946045, 0.00939941,
#                     0.00564575],
#                    [-0.00274658, -0.00271606, 0.00836182, ..., 0.0266113, -0.0187988,
#                     0.045166]], dtype=bfloat16)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 2,048 (4.1 KB)
#           type=Param,
#           value=Array([0.443359, 0.439453, 0.820312, ..., 0.449219, 0.511719, 0.417969],      dtype=bfloat16)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 2,048 (4.1 KB)
#           type=Param,
#           value=Array([0.519531, 0.503906, 0.455078, ..., 0.527344, 0.5, 0.523438],      dtype=bfloat16)
#         )
#       }
#     }
#   }
# })

# %%
from jax import tree_util
import jax.numpy as jnp

def check_for_nan_inf(tree):
    def test(x):
        return jnp.isnan(x).any() or jnp.isinf(x).any()
    flagged = tree_util.tree_map(test, tree)
    return flagged

nan_flags = check_for_nan_inf(loaded_weights)
print(nan_flags)
# Out:
# State({
#   'final_norm': {
#     'scale': VariableState( # 1 (1 B)
#       type=Param,
#       value=Array(False, dtype=bool)
#     )
#   },
#   'out_head': {
#     'kernel': VariableState( # 1 (1 B)
#       type=Param,
#       value=Array(False, dtype=bool)
#     )
#   },
#   'tok_emb': {
#     'embedding': VariableState( # 1 (1 B)
#       type=Param,
#       value=Array(False, dtype=bool)
#     )
#   },
#   'trf_blocks': {
#     0: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'out_proj': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       }
#     },
#     1: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'out_proj': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       }
#     },
#     2: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'out_proj': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       }
#     },
#     3: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'out_proj': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       }
#     },
#     4: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'out_proj': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       }
#     },
#     5: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'out_proj': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       }
#     },
#     6: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'out_proj': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       }
#     },
#     7: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'out_proj': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       }
#     },
#     8: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'out_proj': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       }
#     },
#     9: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'out_proj': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       }
#     },
#     10: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'out_proj': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       }
#     },
#     11: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'out_proj': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       }
#     },
#     12: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'out_proj': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       }
#     },
#     13: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'out_proj': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       }
#     },
#     14: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'out_proj': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       }
#     },
#     15: {
#       'att': {
#         'W_key': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_query': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'W_value': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'out_proj': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'ff': {
#         'fc1': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc2': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         },
#         'fc3': {
#           'kernel': VariableState( # 1 (1 B)
#             type=Param,
#             value=Array(False, dtype=bool)
#           )
#         }
#       },
#       'norm1': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       },
#       'norm2': {
#         'scale': VariableState( # 1 (1 B)
#           type=Param,
#           value=Array(False, dtype=bool)
#         )
#       }
#     }
#   }
# })

# %% [markdown]
# ## Loading Pretrained Weights

# %%
# !huggingface-cli login
# Out:
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
#     _|    _|    _|_|      _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|        _|    _|    _|_|_|  _|_|_|_|
#
#     To log in, `huggingface_hub` requires a token generated from https://huggingface.co/settings/tokens .
# Enter your token (input will not be visible):
# Add token as git credential? (Y/n) n
# Token is valid (permission: fineGrained).
# The token `llama-3` has been saved to /root/.cache/huggingface/stored_tokens
# Your token has been saved to /root/.cache/huggingface/token
# Login successful.
# The current active token is: `llama-3`

# %%
from huggingface_hub import hf_hub_download

weights_file = hf_hub_download(
        repo_id=f"meta-llama/Llama-3.2-1B-Instruct",
        filename="model.safetensors",
        local_dir=f"Llama-3.2-1B-Instruct"
    )
# Out:
# model.safetensors:   0%|          | 0.00/2.47G [00:00<?, ?B/s]

# %%
from huggingface_hub import hf_hub_download

tokenizer_file = hf_hub_download(
    repo_id=f"meta-llama/Llama-3.2-1B-Instruct",
    filename="original/tokenizer.model",  # Use the correct filename for the tokenizer
    local_dir=f"Llama-3.2-1B-Instruct/original",  # Specify the subfolder where the tokenizer is located (if any)
)
# Out:
# tokenizer.model:   0%|          | 0.00/2.18M [00:00<?, ?B/s]

# %% [markdown]
# ### Checking model layer names

# %%
from safetensors.torch import load_file

# Path to the safetensors file
safetensor_path = "/content/Llama-3.2-1B-Instruct/model.safetensors"

# Load the tensors from the safetensor file
pt_state_dict = load_file(safetensor_path)

# Print out the names and shapes of the tensors
for name, tensor in pt_state_dict.items():
    print(name, tensor.shape)


#do not run this always as this loads the entire model in memory, run it once only to see the layer names
# Out:
# model.embed_tokens.weight torch.Size([128256, 2048])
# model.layers.0.input_layernorm.weight torch.Size([2048])
# model.layers.0.mlp.down_proj.weight torch.Size([2048, 8192])
# model.layers.0.mlp.gate_proj.weight torch.Size([8192, 2048])
# model.layers.0.mlp.up_proj.weight torch.Size([8192, 2048])
# model.layers.0.post_attention_layernorm.weight torch.Size([2048])
# model.layers.0.self_attn.k_proj.weight torch.Size([512, 2048])
# model.layers.0.self_attn.o_proj.weight torch.Size([2048, 2048])
# model.layers.0.self_attn.q_proj.weight torch.Size([2048, 2048])
# model.layers.0.self_attn.v_proj.weight torch.Size([512, 2048])
# model.layers.1.input_layernorm.weight torch.Size([2048])
# model.layers.1.mlp.down_proj.weight torch.Size([2048, 8192])
# model.layers.1.mlp.gate_proj.weight torch.Size([8192, 2048])
# model.layers.1.mlp.up_proj.weight torch.Size([8192, 2048])
# model.layers.1.post_attention_layernorm.weight torch.Size([2048])
# model.layers.1.self_attn.k_proj.weight torch.Size([512, 2048])
# model.layers.1.self_attn.o_proj.weight torch.Size([2048, 2048])
# model.layers.1.self_attn.q_proj.weight torch.Size([2048, 2048])
# model.layers.1.self_attn.v_proj.weight torch.Size([512, 2048])
# model.layers.10.input_layernorm.weight torch.Size([2048])
# model.layers.10.mlp.down_proj.weight torch.Size([2048, 8192])
# model.layers.10.mlp.gate_proj.weight torch.Size([8192, 2048])
# model.layers.10.mlp.up_proj.weight torch.Size([8192, 2048])
# model.layers.10.post_attention_layernorm.weight torch.Size([2048])
# model.layers.10.self_attn.k_proj.weight torch.Size([512, 2048])
# model.layers.10.self_attn.o_proj.weight torch.Size([2048, 2048])
# model.layers.10.self_attn.q_proj.weight torch.Size([2048, 2048])
# model.layers.10.self_attn.v_proj.weight torch.Size([512, 2048])
# model.layers.11.input_layernorm.weight torch.Size([2048])
# model.layers.11.mlp.down_proj.weight torch.Size([2048, 8192])
# model.layers.11.mlp.gate_proj.weight torch.Size([8192, 2048])
# model.layers.11.mlp.up_proj.weight torch.Size([8192, 2048])
# model.layers.11.post_attention_layernorm.weight torch.Size([2048])
# model.layers.11.self_attn.k_proj.weight torch.Size([512, 2048])
# model.layers.11.self_attn.o_proj.weight torch.Size([2048, 2048])
# model.layers.11.self_attn.q_proj.weight torch.Size([2048, 2048])
# model.layers.11.self_attn.v_proj.weight torch.Size([512, 2048])
# model.layers.12.input_layernorm.weight torch.Size([2048])
# model.layers.12.mlp.down_proj.weight torch.Size([2048, 8192])
# model.layers.12.mlp.gate_proj.weight torch.Size([8192, 2048])
# model.layers.12.mlp.up_proj.weight torch.Size([8192, 2048])
# model.layers.12.post_attention_layernorm.weight torch.Size([2048])
# model.layers.12.self_attn.k_proj.weight torch.Size([512, 2048])
# model.layers.12.self_attn.o_proj.weight torch.Size([2048, 2048])
# model.layers.12.self_attn.q_proj.weight torch.Size([2048, 2048])
# model.layers.12.self_attn.v_proj.weight torch.Size([512, 2048])
# model.layers.13.input_layernorm.weight torch.Size([2048])
# model.layers.13.mlp.down_proj.weight torch.Size([2048, 8192])
# model.layers.13.mlp.gate_proj.weight torch.Size([8192, 2048])
# model.layers.13.mlp.up_proj.weight torch.Size([8192, 2048])
# model.layers.13.post_attention_layernorm.weight torch.Size([2048])
# model.layers.13.self_attn.k_proj.weight torch.Size([512, 2048])
# model.layers.13.self_attn.o_proj.weight torch.Size([2048, 2048])
# model.layers.13.self_attn.q_proj.weight torch.Size([2048, 2048])
# model.layers.13.self_attn.v_proj.weight torch.Size([512, 2048])
# model.layers.14.input_layernorm.weight torch.Size([2048])
# model.layers.14.mlp.down_proj.weight torch.Size([2048, 8192])
# model.layers.14.mlp.gate_proj.weight torch.Size([8192, 2048])
# model.layers.14.mlp.up_proj.weight torch.Size([8192, 2048])
# model.layers.14.post_attention_layernorm.weight torch.Size([2048])
# model.layers.14.self_attn.k_proj.weight torch.Size([512, 2048])
# model.layers.14.self_attn.o_proj.weight torch.Size([2048, 2048])
# model.layers.14.self_attn.q_proj.weight torch.Size([2048, 2048])
# model.layers.14.self_attn.v_proj.weight torch.Size([512, 2048])
# model.layers.15.input_layernorm.weight torch.Size([2048])
# model.layers.15.mlp.down_proj.weight torch.Size([2048, 8192])
# model.layers.15.mlp.gate_proj.weight torch.Size([8192, 2048])
# model.layers.15.mlp.up_proj.weight torch.Size([8192, 2048])
# model.layers.15.post_attention_layernorm.weight torch.Size([2048])
# model.layers.15.self_attn.k_proj.weight torch.Size([512, 2048])
# model.layers.15.self_attn.o_proj.weight torch.Size([2048, 2048])
# model.layers.15.self_attn.q_proj.weight torch.Size([2048, 2048])
# model.layers.15.self_attn.v_proj.weight torch.Size([512, 2048])
# model.layers.2.input_layernorm.weight torch.Size([2048])
# model.layers.2.mlp.down_proj.weight torch.Size([2048, 8192])
# model.layers.2.mlp.gate_proj.weight torch.Size([8192, 2048])
# model.layers.2.mlp.up_proj.weight torch.Size([8192, 2048])
# model.layers.2.post_attention_layernorm.weight torch.Size([2048])
# model.layers.2.self_attn.k_proj.weight torch.Size([512, 2048])
# model.layers.2.self_attn.o_proj.weight torch.Size([2048, 2048])
# model.layers.2.self_attn.q_proj.weight torch.Size([2048, 2048])
# model.layers.2.self_attn.v_proj.weight torch.Size([512, 2048])
# model.layers.3.input_layernorm.weight torch.Size([2048])
# model.layers.3.mlp.down_proj.weight torch.Size([2048, 8192])
# model.layers.3.mlp.gate_proj.weight torch.Size([8192, 2048])
# model.layers.3.mlp.up_proj.weight torch.Size([8192, 2048])
# model.layers.3.post_attention_layernorm.weight torch.Size([2048])
# model.layers.3.self_attn.k_proj.weight torch.Size([512, 2048])
# model.layers.3.self_attn.o_proj.weight torch.Size([2048, 2048])
# model.layers.3.self_attn.q_proj.weight torch.Size([2048, 2048])
# model.layers.3.self_attn.v_proj.weight torch.Size([512, 2048])
# model.layers.4.input_layernorm.weight torch.Size([2048])
# model.layers.4.mlp.down_proj.weight torch.Size([2048, 8192])
# model.layers.4.mlp.gate_proj.weight torch.Size([8192, 2048])
# model.layers.4.mlp.up_proj.weight torch.Size([8192, 2048])
# model.layers.4.post_attention_layernorm.weight torch.Size([2048])
# model.layers.4.self_attn.k_proj.weight torch.Size([512, 2048])
# model.layers.4.self_attn.o_proj.weight torch.Size([2048, 2048])
# model.layers.4.self_attn.q_proj.weight torch.Size([2048, 2048])
# model.layers.4.self_attn.v_proj.weight torch.Size([512, 2048])
# model.layers.5.input_layernorm.weight torch.Size([2048])
# model.layers.5.mlp.down_proj.weight torch.Size([2048, 8192])
# model.layers.5.mlp.gate_proj.weight torch.Size([8192, 2048])
# model.layers.5.mlp.up_proj.weight torch.Size([8192, 2048])
# model.layers.5.post_attention_layernorm.weight torch.Size([2048])
# model.layers.5.self_attn.k_proj.weight torch.Size([512, 2048])
# model.layers.5.self_attn.o_proj.weight torch.Size([2048, 2048])
# model.layers.5.self_attn.q_proj.weight torch.Size([2048, 2048])
# model.layers.5.self_attn.v_proj.weight torch.Size([512, 2048])
# model.layers.6.input_layernorm.weight torch.Size([2048])
# model.layers.6.mlp.down_proj.weight torch.Size([2048, 8192])
# model.layers.6.mlp.gate_proj.weight torch.Size([8192, 2048])
# model.layers.6.mlp.up_proj.weight torch.Size([8192, 2048])
# model.layers.6.post_attention_layernorm.weight torch.Size([2048])
# model.layers.6.self_attn.k_proj.weight torch.Size([512, 2048])
# model.layers.6.self_attn.o_proj.weight torch.Size([2048, 2048])
# model.layers.6.self_attn.q_proj.weight torch.Size([2048, 2048])
# model.layers.6.self_attn.v_proj.weight torch.Size([512, 2048])
# model.layers.7.input_layernorm.weight torch.Size([2048])
# model.layers.7.mlp.down_proj.weight torch.Size([2048, 8192])
# model.layers.7.mlp.gate_proj.weight torch.Size([8192, 2048])
# model.layers.7.mlp.up_proj.weight torch.Size([8192, 2048])
# model.layers.7.post_attention_layernorm.weight torch.Size([2048])
# model.layers.7.self_attn.k_proj.weight torch.Size([512, 2048])
# model.layers.7.self_attn.o_proj.weight torch.Size([2048, 2048])
# model.layers.7.self_attn.q_proj.weight torch.Size([2048, 2048])
# model.layers.7.self_attn.v_proj.weight torch.Size([512, 2048])
# model.layers.8.input_layernorm.weight torch.Size([2048])
# model.layers.8.mlp.down_proj.weight torch.Size([2048, 8192])
# model.layers.8.mlp.gate_proj.weight torch.Size([8192, 2048])
# model.layers.8.mlp.up_proj.weight torch.Size([8192, 2048])
# model.layers.8.post_attention_layernorm.weight torch.Size([2048])
# model.layers.8.self_attn.k_proj.weight torch.Size([512, 2048])
# model.layers.8.self_attn.o_proj.weight torch.Size([2048, 2048])
# model.layers.8.self_attn.q_proj.weight torch.Size([2048, 2048])
# model.layers.8.self_attn.v_proj.weight torch.Size([512, 2048])
# model.layers.9.input_layernorm.weight torch.Size([2048])
# model.layers.9.mlp.down_proj.weight torch.Size([2048, 8192])
# model.layers.9.mlp.gate_proj.weight torch.Size([8192, 2048])
# model.layers.9.mlp.up_proj.weight torch.Size([8192, 2048])
# model.layers.9.post_attention_layernorm.weight torch.Size([2048])
# model.layers.9.self_attn.k_proj.weight torch.Size([512, 2048])
# model.layers.9.self_attn.o_proj.weight torch.Size([2048, 2048])
# model.layers.9.self_attn.q_proj.weight torch.Size([2048, 2048])
# model.layers.9.self_attn.v_proj.weight torch.Size([512, 2048])
# model.norm.weight torch.Size([2048])

# %%
(pt_state_dict['model.embed_tokens.weight']).shape
# Out:
# torch.Size([128256, 2048])

# %%
(model.tok_emb.embedding.value).shape
# Out:
# (128256, 2048)

# %% [markdown]
# ### Function for weight key mapping and loading

# %%
from safetensors.numpy import safe_open
import jax.numpy as jnp
import gc
from tqdm import tqdm

def assign(dest, src, name):
    if dest.shape != src.shape:
        raise ValueError(
            f"[Shape Mismatch] → {name}\n"
            f"  Expected: {dest.shape}\n"
            f"  Received: {src.shape}\n"
        )
    # if dest.dtype != src.dtype:
    #     print(
    #         f"[Warning: Dtype Mismatch] → {name}\n"
    #         f"  Expected: {dest.dtype}\n"
    #         f"  Received: {src.dtype}\n"
    #     )
    return src

def update_model_from_safetensors(model, safetensors_path):
    with safe_open(safetensors_path, framework="np") as f:
        for key in tqdm(f.keys(), desc="Loading Weights"):
            tensor = jnp.array(f.get_tensor(key))

            if key == 'model.embed_tokens.weight':
                model.tok_emb.embedding.value = assign(model.tok_emb.embedding.value, tensor, key)

            elif key.startswith('model.layers.'):
                parts = key.split('.')
                layer_id = int(parts[2])
                subkey = '.'.join(parts[3:])
                block = model.trf_blocks[layer_id]
                # print(subkey)

                if subkey == 'self_attn.q_proj.weight':
                    block.att.W_query.kernel.value = assign(block.att.W_query.kernel.value, tensor.T, key)
                elif subkey == 'self_attn.k_proj.weight':
                    block.att.W_key.kernel.value = assign(block.att.W_key.kernel.value, tensor.T, key)
                elif subkey == 'self_attn.v_proj.weight':
                    block.att.W_value.kernel.value = assign(block.att.W_value.kernel.value, tensor.T, key)
                elif subkey == 'self_attn.o_proj.weight':
                    block.att.out_proj.kernel.value = assign(block.att.out_proj.kernel.value, tensor.T, key)
                elif subkey == 'input_layernorm.weight':
                    block.norm1.scale.value = assign(block.norm1.scale.value, tensor, key)
                elif subkey == 'post_attention_layernorm.weight':
                    block.norm2.scale.value = assign(block.norm2.scale.value, tensor, key)
                elif subkey == 'mlp.gate_proj.weight':
                    block.ff.fc1.kernel.value = assign(block.ff.fc1.kernel.value, tensor.T, key)
                elif subkey == 'mlp.up_proj.weight':
                    block.ff.fc2.kernel.value = assign(block.ff.fc2.kernel.value, tensor.T, key)
                elif subkey == 'mlp.down_proj.weight':
                    block.ff.fc3.kernel.value = assign(block.ff.fc3.kernel.value, tensor.T, key)

            elif key == 'model.norm.weight':
                model.final_norm.scale.value = assign(model.final_norm.scale.value, tensor, key)

            elif key == 'lm_head.weight':
                model.out_head.kernel.value = assign(model.out_head.kernel.value, tensor.T, key)

            del tensor
            gc.collect()

# %%
# LLAMA32_CONFIG = {
#         "vocab_size": 128_256,
#         "context_length": 131_072,
#         "embedding_dim": 2048,
#         "n_heads": 32,
#         "n_layers": 16,
#         "hidden_dim": 8192,
#         "n_kv_groups": 8,
#         "rope_base": 500_000.0,
#         "dtype": jnp.bfloat16,
#         "param_dtype": jnp.bfloat16,

#         "rope_freq": {
#             "factor": 32.0,
#             "low_freq_factor": 1.0,
#             "high_freq_factor": 4.0,
#             "original_context_length": 8192,
#         }
#     }

args = ModelArgs(**LLAMA32_CONFIG)

# Step 2: Instantiate model (params not allocated yet)
model = Llama3Model(args=args, rngs=nnx.Rngs(0))

# Step 3: Load weights from .safetensors file
update_model_from_safetensors(model, "/content/Llama-3.2-1B-Instruct/model.safetensors")
# Out:
# Loading Weights: 100%|██████████| 146/146 [01:11<00:00,  2.04it/s]

# %%
update_model_from_safetensors(model, "/content/Llama-3.2-1B-Instruct/model.safetensors")

# %%
model.tok_emb.embedding.shape
# Out:
# (128256, 2048)

# %%
model.out_head.kernel = nnx.Param(model.tok_emb.embedding.value.T)

# %%
def get_all_params(module):
    params = []

    if isinstance(module, nnx.Param):
        params.append(module)
    elif isinstance(module, nnx.Module):
        for attr in vars(module).values():
            params.extend(get_all_params(attr))
    elif isinstance(module, (list, tuple)):
        for item in module:
            params.extend(get_all_params(item))
    elif isinstance(module, dict):
        for item in module.values():
            params.extend(get_all_params(item))

    return params

def count_params_and_size(model):
    params = get_all_params(model)
    total_params = sum(p.value.size for p in params)
    total_bytes = sum(p.value.size * p.value.dtype.itemsize for p in params)
    return total_params, total_bytes

def pretty_size(num_bytes):
    if num_bytes < 1024**2:
        return f"{num_bytes / 1024:.2f} KB"
    elif num_bytes < 1024**3:
        return f"{num_bytes / (1024**2):.2f} MB"
    else:
        return f"{num_bytes / (1024**3):.2f} GB"

# Run it
total_params, total_bytes = count_params_and_size(model)
print(f"Total Parameters: {total_params:,}")
print(f"Model Size: {pretty_size(total_bytes)}")
# Out:
# Total Parameters: 1,498,482,688
# Model Size: 2.79 GB

# %% [markdown]
# ## Chat Inference

# %%
# !pip install blobfile
# Out:
# Requirement already satisfied: blobfile in /usr/local/lib/python3.11/dist-packages (3.0.0)
# Requirement already satisfied: pycryptodomex>=3.8 in /usr/local/lib/python3.11/dist-packages (from blobfile) (3.22.0)
# Requirement already satisfied: urllib3<3,>=1.25.3 in /usr/local/lib/python3.11/dist-packages (from blobfile) (2.3.0)
# Requirement already satisfied: lxml>=4.9 in /usr/local/lib/python3.11/dist-packages (from blobfile) (5.3.1)
# Requirement already satisfied: filelock>=3.0 in /usr/local/lib/python3.11/dist-packages (from blobfile) (3.18.0)

# %%
from tiktoken.load import load_tiktoken_bpe

# Path to your tokenizer.model file
tokenizer_path = "/content/Llama-3.2-1B-Instruct/original/tokenizer.model" # update the path if necessary

# Load the tokenizer
mergeable_ranks = load_tiktoken_bpe(tokenizer_path)

# Access the vocabulary (tokens and IDs)
vocabulary = mergeable_ranks.items()

# Print or inspect the vocabulary
for token, token_id in vocabulary:
    print(f"Token: {token}, Token ID: {token_id}")

# %%
from huggingface_hub import hf_hub_download
from tiktoken.load import load_tiktoken_bpe

import os
from pathlib import Path

import tiktoken


class Tokenizer:
    def __init__(self, model_path):
        assert os.path.isfile(model_path), f"Model file {model_path} not found"
        mergeable_ranks = load_tiktoken_bpe(model_path)

        self.special_tokens = {
            "<|begin_of_text|>": 128000,
            "<|end_of_text|>": 128001,
            "<|start_header_id|>": 128006,
            "<|end_header_id|>": 128007,
            "<|eot_id|>": 128009,
        }
        self.special_tokens.update({
            f"<|reserved_{i}|>": 128002 + i for i in range(256) if (128002 + i) not in self.special_tokens.values()
        })

        self.model = tiktoken.Encoding(
            name=Path(model_path).name,
            pat_str=r"(?i:'s|'t|'re|'ve|'m|'ll|'d)|[^\r\n\p{L}\p{N}]?\p{L}+|\p{N}{1,3}| ?[^\s\p{L}\p{N}]+[\r\n]*|\s*[\r\n]+|\s+(?!\S)|\s+",
            mergeable_ranks=mergeable_ranks,
            special_tokens=self.special_tokens
        )


    def encode(self, text, bos=False, eos=False, allowed_special=set(), disallowed_special=()):
        if bos:
            tokens = [self.special_tokens["<|begin_of_text|>"]]
        else:
            tokens = []

        tokens += self.model.encode(text, allowed_special=allowed_special, disallowed_special=disallowed_special)

        if eos:
            tokens.append(self.special_tokens["<|end_of_text|>"])
        return tokens

    def decode(self, tokens):
        return self.model.decode(tokens)


class ChatFormat:
    def __init__(self, tokenizer):
        self.tokenizer = tokenizer

    def encode_header(self, message):
        tokens = []
        tokens.append(self.tokenizer.special_tokens["<|start_header_id|>"])
        tokens.extend(self.tokenizer.encode(message["role"], bos=False, eos=False))
        tokens.append(self.tokenizer.special_tokens["<|end_header_id|>"])
        tokens.extend(self.tokenizer.encode("\n\n", bos=False, eos=False))
        return tokens

    def encode(self, text):
        message = {
            "role": "user",
            "content": text
        }

        tokens = self.encode_header(message)
        tokens.extend(
            self.tokenizer.encode(message["content"].strip(), bos=False, eos=False)
        )
        tokens.append(self.tokenizer.special_tokens["<|eot_id|>"])
        return tokens

    def decode(self, token_ids):
        return self.tokenizer.decode(token_ids)

# Assuming LLAMA_SIZE_STR is defined (e.g., "1B")
LLAMA_SIZE_STR = "1B"

tokenizer_file_path = hf_hub_download(
    repo_id=f"meta-llama/Llama-3.2-{LLAMA_SIZE_STR}-Instruct",
    filename="original/tokenizer.model",
    local_dir=f"Llama-3.2-{LLAMA_SIZE_STR}-Instruct"
)

tokenizer = Tokenizer(tokenizer_file_path)
chat_tokenizer = ChatFormat(tokenizer)

# %% [markdown]
# ### Miscellaneous Tests

# %%
input_ids = tokenizer.encode("What do llamas eat?")
input_ids
# Out:
# [3923, 656, 9507, 29189, 8343, 30]

# %%
input_ids = tokenizer.encode("<|start_header_id|> What do llamas eat?")
input_ids
# Out:
# [27, 91, 2527, 8932, 851, 91, 29, 3639, 656, 9507, 29189, 8343, 30]

# %%
tokenizer.decode(input_ids)
# Out:
# '<|start_header_id|> What do llamas eat?'

# %%
input = jnp.array(input_ids).reshape(len(input_ids),1)

# %%
output = model(input)
output.shape
# Out:
# (13, 1, 128256)

# %%
jnp.argmax(output[-1])
# Out:
# Array(53751, dtype=int32)

# %%
import torch
tokenizer.decode([53751])
# Out:
# ' Improvement'

# %% [markdown]
# ## Inference

# %%
import jax
import jax.numpy as jnp

def text_to_token_ids(text, tokenizer):
    encoded = tokenizer.encode(text)
    encoded_tensor = jnp.expand_dims(jnp.array(encoded),axis=0)  # add batch dimension
    return encoded_tensor


def token_ids_to_text(token_ids, tokenizer):
    flat = token_ids.squeeze(0)  # remove batch dimension
    return tokenizer.decode(flat.tolist())

def generate(model, idx, max_new_tokens, context_size, temperature=0.0, top_k=None, eos_id=None):
    """Generates text using the given model and parameters."""

    for _ in range(max_new_tokens):
        idx_cond = idx[:, -context_size:]
        logits = model(idx_cond)  # Assuming model is already JAX-compatible
        logits = logits[:, -1, :]

        # Top-k sampling
        if top_k is not None:
            top_logits, _ = jax.lax.top_k(logits, top_k)
            min_val = top_logits[:, -1]
            logits = jnp.where(logits < min_val, -jnp.inf, logits)

        # Temperature scaling
        if temperature > 0.0:
            logits /= temperature
            probs = jax.nn.softmax(logits, axis=-1)
            idx_next = jax.random.categorical(jax.random.PRNGKey(0), probs, axis=-1, shape=(logits.shape[0], 1))
        else:
            idx_next = jnp.argmax(logits, axis=-1, keepdims=True)

        # Early stopping with eos_id
        if eos_id is not None and jnp.all(idx_next == eos_id):
            break

        idx = jnp.concatenate([idx, idx_next], axis=1)

    return idx

# %%
PROMPT = "What do llamas eat?"

token_ids = generate(
    model=model,
    idx=text_to_token_ids(PROMPT, chat_tokenizer),
    max_new_tokens=50,
    context_size=LLAMA32_CONFIG["context_length"],
    top_k=1,
    temperature=0.
)

output_text = token_ids_to_text(token_ids, tokenizer)

# %%
#5 tokens
output_text
# Out:
# '<|start_header_id|>user<|end_header_id|>\n\nWhat do llamas eat?<|eot_id|><|start_header_id|>assistant<|end_header_id|>\n\nL'

# %%
# 50 tokens
output_text
# Out:
# '<|start_header_id|>user<|end_header_id|>\n\nWhat do llamas eat?<|eot_id|><|start_header_id|>assistant<|end_header_id|>\n\nLlamas are herbivores, which means they primarily eat plants. Their diet consists mainly of:\n\n1. Grasses: Llamas love to graze on various types of grasses, including tall grasses and grass'
